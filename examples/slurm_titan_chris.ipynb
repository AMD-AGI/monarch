# %%
# %cd /mnt/models/mreso/monarch/examples/
# Out:
# /mnt/models/mreso/monarch/examples

# %%
import os
os.environ.setdefault("GPU_MAX_HW_QUEUES", "2")
os.environ.setdefault("TORCH_NCCL_HIGH_PRIORITY", "1")
os.environ.setdefault("NCCL_CHECKS_DISABLE", "1")
os.environ.setdefault("NCCL_IB_GID_INDEX", "3")
os.environ.setdefault("NCCL_CROSS_NIC", "0")
os.environ.setdefault("CUDA_DEVICE_MAX_CONNECTIONS", "1")
os.environ.setdefault("NCCL_PROTO", "Simple")
os.environ.setdefault("RCCL_MSCCL_ENABLE", "0")
os.environ.setdefault("TOKENIZERS_PARALLELISM", "false")
os.environ.setdefault("HSA_NO_SCRATCH_RECLAIM", "1")
os.environ.setdefault("NCCL_PXN_DISABLE", "0")
os.environ.setdefault("NCCL_P2P_NET_CHUNKSIZE", "262144")
# Out:
# '262144'

# %% [markdown]
# ## Monarch + TorchTitan on SLURM
# This example notebook demonstrates how you can easily run and iterate on a distributed training job with Monarch and TorchTitan.
#
# #### Prerequisites
# Please make sure your environment is setup for this notebook:
# 1. Install Monarch nightly: https://github.com/meta-pytorch/monarch/blob/main/scripts/install_nightly.py
# 2. Install Titan nightly: https://github.com/pytorch/torchtitan?tab=readme-ov-file#nightly-builds
# 3. Ensure you have a valid Titan model config in the script directory (i.e: https://github.com/pytorch/torchtitan/blob/main/torchtitan/models/llama3/train_configs/debug_model.toml)

# %% [markdown]
# ### 1. Reserve your SLURM job
# If necessary, update paramaters for your cluster:
# - host_type: TorchX named resource for your cluster (default: "gpu.xlarge")
# - host_memory: Memory per machine in MB (default: 2062607)
#
# For more information on TorchX resources: https://docs.pytorch.org/torchx/main/specs.html#resource

# %%
# (c) Meta Platforms, Inc. and affiliates. Confidential and proprietary.

from slurm.utils import get_appdef, get_server_info, create_proc_mesh


num_nodes = 1 # assign for your system
appdef = await get_appdef(
    num_nodes,
    # host_type = ...
)
server_info = await get_server_info(
    appdef,
    # host_memory = ...
)
# Out:
# <string>:8: FutureWarning: Setting `workspace='/mnt/models/mreso/monarch/examples'` is deprecated. Use `workspace=monarch.tools.config.workspace.Workspace(dirs=['/mnt/models/mreso/monarch/examples'])` instead.
# torchx.schedulers.slurm_scheduler 2025-10-02 19:53:34 INFO unable to get job info for `monarch-root` with `squeue` (squeue: error: Invalid job id: monarch-root
# ), trying `sacct`
# torchx.schedulers.slurm_scheduler 2025-10-02 19:53:34 INFO unable to get job info for `monarch-root` with `sacct` (sacct: fatal: Bad job/step specified: monarch-root
# )
# monarch.tools.commands 2025-10-02 19:53:34 INFO no existing RUNNING server `slurm:///monarch-root` creating new one...
# torchx.runner.api 2025-10-02 19:53:34 INFO Tracker configurations: {}
# torchx.runner.api 2025-10-02 19:53:34 INFO Checking for changes in workspace `/root/.monarch/out/tmpio6n_axj/workspace`...
# torchx.runner.api 2025-10-02 19:53:34 INFO To disable workspaces pass: --workspace="" from CLI or workspace=None programmatically.
# torchx.runner.api 2025-10-02 19:53:34 INFO Reusing original image `monarch_default_workspace:latest` for role[0]=mesh0. Either a patch was built or no changes to workspace was detected.
# monarch.tools.commands 2025-10-02 19:53:34 INFO created new `slurm:///1305` waiting for it to be ready...
# app_id='monarch-root'
# slurm_24_11_0=(24, 11)
# slurm_version=(21, 8)
# slurm_24_11_0=(24, 11)
# slurm_version=(21, 8)
# slurm_24_11_0=(24, 11)
# slurm_version=(21, 8)
# slurm_24_11_0=(24, 11)
# slurm_version=(21, 8)
# script='#!/bin/bash\n#\n# Generated by TorchX 0.8.0dev0\n# Run with: sbatch --parsable /tmp/tmp4qc5mee9/torchx-sbatch.sh\n#\n#SBATCH --job-name=mesh0-0 --requeue --ntasks-per-node=1 --cpus-per-task=64 --mem=2062607 --gpus-per-node=8\n#SBATCH hetjob\n#SBATCH --job-name=mesh0-1 --requeue --ntasks-per-node=1 --cpus-per-task=64 --mem=2062607 --gpus-per-node=8\n#SBATCH hetjob\n#SBATCH --job-name=mesh0-2 --requeue --ntasks-per-node=1 --cpus-per-task=64 --mem=2062607 --gpus-per-node=8\n#SBATCH hetjob\n#SBATCH --job-name=mesh0-3 --requeue --ntasks-per-node=1 --cpus-per-task=64 --mem=2062607 --gpus-per-node=8\n\nset -evx\n\nexport PYTHONUNBUFFERED=1\nexport SLURM_UNBUFFEREDIO=1\nexport TORCHX_MAX_RETRIES=0\n\nset +e\nsrun --output=slurm-"$SLURM_JOB_ID"-mesh0-0.out --error=slurm-"$SLURM_JOB_ID"-mesh0-0.err --wait=60 --kill-on-bad-exit=1 --export=ALL,WORKSPACE_DIR=monarch_default_workspace:latest/workspace,PYTHONPATH=monarch_default_workspace:latest/workspace/,CONDA_DIR=monarch_default_workspace:latest/conda,TORCHX_JOB_ID=slurm:///"$SLURM_JOB_ID",TORCHX_INTERNAL_SESSION_ID=e1b17cf5-b371-47c5-a095-f8b4b6aa8c4f process_allocator --port=26600 --program=monarch_bootstrap :\\\n     --output=slurm-"$SLURM_JOB_ID"-mesh0-1.out --error=slurm-"$SLURM_JOB_ID"-mesh0-1.err --wait=60 --kill-on-bad-exit=1 --export=ALL,WORKSPACE_DIR=monarch_default_workspace:latest/workspace,PYTHONPATH=monarch_default_workspace:latest/workspace/,CONDA_DIR=monarch_default_workspace:latest/conda,TORCHX_JOB_ID=slurm:///"$SLURM_JOB_ID",TORCHX_INTERNAL_SESSION_ID=e1b17cf5-b371-47c5-a095-f8b4b6aa8c4f process_allocator --port=26600 --program=monarch_bootstrap :\\\n     --output=slurm-"$SLURM_JOB_ID"-mesh0-2.out --error=slurm-"$SLURM_JOB_ID"-mesh0-2.err --wait=60 --kill-on-bad-exit=1 --export=ALL,WORKSPACE_DIR=monarch_default_workspace:latest/workspace,PYTHONPATH=monarch_default_workspace:latest/workspace/,CONDA_DIR=monarch_default_workspace:latest/conda,TORCHX_JOB_ID=slurm:///"$SLURM_JOB_ID",TORCHX_INTERNAL_SESSION_ID=e1b17cf5-b371-47c5-a095-f8b4b6aa8c4f process_allocator --port=26600 --program=monarch_bootstrap :\\\n     --output=slurm-"$SLURM_JOB_ID"-mesh0-3.out --error=slurm-"$SLURM_JOB_ID"-mesh0-3.err --wait=60 --kill-on-bad-exit=1 --export=ALL,WORKSPACE_DIR=monarch_default_workspace:latest/workspace,PYTHONPATH=monarch_default_workspace:latest/workspace/,CONDA_DIR=monarch_default_workspace:latest/conda,TORCHX_JOB_ID=slurm:///"$SLURM_JOB_ID",TORCHX_INTERNAL_SESSION_ID=e1b17cf5-b371-47c5-a095-f8b4b6aa8c4f process_allocator --port=26600 --program=monarch_bootstrap\nexitcode=$?\nset -e\n\necho "job exited with code $exitcode"\nif [ $exitcode -ne 0 ]; then\n    if [ "$TORCHX_MAX_RETRIES" -gt "${SLURM_RESTART_COUNT:-0}" ]; then\n        scontrol requeue "$SLURM_JOB_ID"\n    fi\n    exit $exitcode\nfi\n'
# req.cmd=['sbatch', '--parsable', '/tmp/tmp4qc5mee9/torchx-sbatch.sh']
# app_id='1305'
# output='{\n  "meta": {\n    "plugin": {\n      "type": "openapi\\/v0.0.37",\n      "name": "Slurm OpenAPI v0.0.37"\n    },\n    "Slurm": {\n      "version": {\n        "major": 21,\n        "micro": 5,\n        "minor": 8\n      },\n      "release": "21.08.5"\n    }\n  },\n  "errors": [\n  ],\n  "jobs": [\n    {\n      "account": "",\n      "accrue_time": 0,\n      "admin_comment": "",\n      "array_job_id": 0,\n      "array_task_id": null,\n      "array_max_tasks": 0,\n      "array_task_string": "",\n      "association_id": 0,\n      "batch_features": "",\n      "batch_flag": true,\n      "batch_host": "",\n      "flags": [\n        "JOB_CPUS_SET ",\n        "JOB_MEM_SET"\n      ],\n      "burst_buffer": "",\n      "burst_buffer_state": "",\n      "cluster": "vultr-mi325x-torch",\n      "cluster_features": "",\n      "command": "\\/tmp\\/tmp4qc5mee9\\/torchx-sbatch.sh",\n      "comment": "",\n      "contiguous": false,\n      "core_spec": null,\n      "thread_spec": null,\n      "cores_per_socket": null,\n      "billable_tres": null,\n      "cpus_per_task": null,\n      "cpu_frequency_minimum": null,\n      "cpu_frequency_maximum": null,\n      "cpu_frequency_governor": null,\n      "cpus_per_tres": "",\n      "deadline": 0,\n      "delay_boot": 0,\n      "dependency": "",\n      "derived_exit_code": 0,\n      "eligible_time": 1759434814,\n      "end_time": 0,\n      "excluded_nodes": "",\n      "exit_code": 0,\n      "features": "",\n      "federation_origin": "",\n      "federation_siblings_active": "",\n      "federation_siblings_viable": "",\n      "gres_detail": [\n      ],\n      "group_id": 0,\n      "job_id": 1305,\n      "job_resources": {\n      },\n      "job_state": "PENDING",\n      "last_sched_evaluation": 1759434814,\n      "licenses": "",\n      "max_cpus": 0,\n      "max_nodes": 0,\n      "mcs_label": "",\n      "memory_per_tres": "",\n      "name": "mesh0-0",\n      "nodes": "",\n      "nice": null,\n      "tasks_per_core": null,\n      "tasks_per_node": 1,\n      "tasks_per_socket": null,\n      "tasks_per_board": 0,\n      "cpus": 64,\n      "node_count": 1,\n      "tasks": 1,\n      "het_job_id": 1305,\n      "het_job_id_set": "1305-1308",\n      "het_job_offset": 0,\n      "partition": "vultr-mi325x-torch",\n      "memory_per_node": 2062607,\n      "memory_per_cpu": null,\n      "minimum_cpus_per_node": 64,\n      "minimum_tmp_disk_per_node": 0,\n      "preempt_time": 0,\n      "pre_sus_time": 0,\n      "priority": 4294900821,\n      "profile": null,\n      "qos": "",\n      "reboot": false,\n      "required_nodes": "",\n      "requeue": true,\n      "resize_time": 0,\n      "restart_cnt": 0,\n      "resv_name": "",\n      "shared": null,\n      "show_flags": [\n        "SHOW_ALL",\n        "SHOW_DETAIL",\n        "SHOW_LOCAL"\n      ],\n      "sockets_per_board": 0,\n      "sockets_per_node": null,\n      "start_time": 0,\n      "state_description": "",\n      "state_reason": "None",\n      "standard_error": "",\n      "standard_input": "\\/dev\\/null",\n      "standard_output": "",\n      "submit_time": 1759434814,\n      "suspend_time": 0,\n      "system_comment": "",\n      "time_limit": null,\n      "time_minimum": 0,\n      "threads_per_core": null,\n      "tres_bind": "",\n      "tres_freq": "",\n      "tres_per_job": "",\n      "tres_per_node": "gres:gpu:8",\n      "tres_per_socket": "",\n      "tres_per_task": "",\n      "tres_req_str": "cpu=64,mem=2062607M,node=1,billing=64",\n      "tres_alloc_str": "",\n      "user_id": 0,\n      "user_name": "",\n      "wckey": "",\n      "current_working_directory": "\\/mnt\\/models\\/mreso\\/monarch\\/examples"\n    },\n    {\n      "account": "",\n      "accrue_time": 0,\n      "admin_comment": "",\n      "array_job_id": 0,\n      "array_task_id": null,\n      "array_max_tasks": 0,\n      "array_task_string": "",\n      "association_id": 0,\n      "batch_features": "",\n      "batch_flag": true,\n      "batch_host": "",\n      "flags": [\n        "JOB_CPU ...
# jobs=[{'account': '', 'accrue_time': 0, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': '', 'flags': ['JOB_CPUS_SET ', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp4qc5mee9/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': None, 'cpus_per_task': None, 'cpu_frequency_minimum': None, 'cpu_frequency_maximum': None, 'cpu_frequency_governor': None, 'cpus_per_tres': '', 'deadline': 0, 'delay_boot': 0, 'dependency': '', 'derived_exit_code': 0, 'eligible_time': 1759434814, 'end_time': 0, 'excluded_nodes': '', 'exit_code': 0, 'features': '', 'federation_origin': '', 'federation_siblings_active': '', 'federation_siblings_viable': '', 'gres_detail': [], 'group_id': 0, 'job_id': 1305, 'job_resources': {}, 'job_state': 'PENDING', 'last_sched_evaluation': 1759434814, 'licenses': '', 'max_cpus': 0, 'max_nodes': 0, 'mcs_label': '', 'memory_per_tres': '', 'name': 'mesh0-0', 'nodes': '', 'nice': None, 'tasks_per_core': None, 'tasks_per_node': 1, 'tasks_per_socket': None, 'tasks_per_board': 0, 'cpus': 64, 'node_count': 1, 'tasks': 1, 'het_job_id': 1305, 'het_job_id_set': '1305-1308', 'het_job_offset': 0, 'partition': 'vultr-mi325x-torch', 'memory_per_node': 2062607, 'memory_per_cpu': None, 'minimum_cpus_per_node': 64, 'minimum_tmp_disk_per_node': 0, 'preempt_time': 0, 'pre_sus_time': 0, 'priority': 4294900821, 'profile': None, 'qos': '', 'reboot': False, 'required_nodes': '', 'requeue': True, 'resize_time': 0, 'restart_cnt': 0, 'resv_name': '', 'shared': None, 'show_flags': ['SHOW_ALL', 'SHOW_DETAIL', 'SHOW_LOCAL'], 'sockets_per_board': 0, 'sockets_per_node': None, 'start_time': 0, 'state_description': '', 'state_reason': 'None', 'standard_error': '', 'standard_input': '/dev/null', 'standard_output': '', 'submit_time': 1759434814, 'suspend_time': 0, 'system_comment': '', 'time_limit': None, 'time_minimum': 0, 'threads_per_core': None, 'tres_bind': '', 'tres_freq': '', 'tres_per_job': '', 'tres_per_node': 'gres:gpu:8', 'tres_per_socket': '', 'tres_per_task': '', 'tres_req_str': 'cpu=64,mem=2062607M,node=1,billing=64', 'tres_alloc_str': '', 'user_id': 0, 'user_name': '', 'wckey': '', 'current_working_directory': '/mnt/models/mreso/monarch/examples'}, {'account': '', 'accrue_time': 0, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': '', 'flags': ['JOB_CPUS_SET ', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp4qc5mee9/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': None, 'cpus_per_task': None, 'cpu_frequency_minimum': None, 'cpu_frequency_maximum': None, 'cpu_frequency_governor': None, 'cpus_per_tres': '', 'deadline': 0, 'delay_boot': 0, 'dependency': '', 'derived_exit_code': 0, 'eligible_time': 1759434814, 'end_time': 0, 'excluded_nodes': '', 'exit_code': 0, 'features': '', 'federation_origin': '', 'federation_siblings_active': '', 'federation_siblings_viable': '', 'gres_detail': [], 'group_id': 0, 'job_id': 1306, 'job_resources': {}, 'job_state': 'PENDING', 'last_sched_evaluation': 1759434814, 'licenses': '', 'max_cpus': 0, 'max_nodes': 0, 'mcs_label': '', 'memory_per_tres': '', 'name': 'mesh0-1', 'nodes': '', 'nice': None, 'tasks_per_core': None, 'tasks_per_node': 1, 'tasks_per_socket': None, 'tasks_per_board': 0, 'cpus': 64, 'node_count': 1, 'tasks': 1, 'het_job_id': 1305, 'het_job_id_set': '1305-1308', 'het_job_offset': 1, 'partition': 'vultr-mi325x-torch', 'memory_per_node': 2062607, 'memory_per_cpu': None, 'minim ...
# job["job_state"]='PENDING'
# state=PENDING (2)
# job["job_state"]='PENDING'
# state=PENDING (2)
# job["job_state"]='PENDING'
# state=PENDING (2)
# job["job_state"]='PENDING'
# state=PENDING (2)
# app_id='1305'
# output='{\n  "meta": {\n    "plugin": {\n      "type": "openapi\\/v0.0.37",\n      "name": "Slurm OpenAPI v0.0.37"\n    },\n    "Slurm": {\n      "version": {\n        "major": 21,\n        "micro": 5,\n        "minor": 8\n      },\n      "release": "21.08.5"\n    }\n  },\n  "errors": [\n  ],\n  "jobs": [\n    {\n      "account": "",\n      "accrue_time": 0,\n      "admin_comment": "",\n      "array_job_id": 0,\n      "array_task_id": null,\n      "array_max_tasks": 0,\n      "array_task_string": "",\n      "association_id": 0,\n      "batch_features": "",\n      "batch_flag": true,\n      "batch_host": "",\n      "flags": [\n        "JOB_CPUS_SET ",\n        "JOB_MEM_SET"\n      ],\n      "burst_buffer": "",\n      "burst_buffer_state": "",\n      "cluster": "vultr-mi325x-torch",\n      "cluster_features": "",\n      "command": "\\/tmp\\/tmp4qc5mee9\\/torchx-sbatch.sh",\n      "comment": "",\n      "contiguous": false,\n      "core_spec": null,\n      "thread_spec": null,\n      "cores_per_socket": null,\n      "billable_tres": null,\n      "cpus_per_task": null,\n      "cpu_frequency_minimum": null,\n      "cpu_frequency_maximum": null,\n      "cpu_frequency_governor": null,\n      "cpus_per_tres": "",\n      "deadline": 0,\n      "delay_boot": 0,\n      "dependency": "",\n      "derived_exit_code": 0,\n      "eligible_time": 1759434814,\n      "end_time": 0,\n      "excluded_nodes": "",\n      "exit_code": 0,\n      "features": "",\n      "federation_origin": "",\n      "federation_siblings_active": "",\n      "federation_siblings_viable": "",\n      "gres_detail": [\n      ],\n      "group_id": 0,\n      "job_id": 1305,\n      "job_resources": {\n      },\n      "job_state": "PENDING",\n      "last_sched_evaluation": 1759434814,\n      "licenses": "",\n      "max_cpus": 0,\n      "max_nodes": 0,\n      "mcs_label": "",\n      "memory_per_tres": "",\n      "name": "mesh0-0",\n      "nodes": "",\n      "nice": null,\n      "tasks_per_core": null,\n      "tasks_per_node": 1,\n      "tasks_per_socket": null,\n      "tasks_per_board": 0,\n      "cpus": 64,\n      "node_count": 1,\n      "tasks": 1,\n      "het_job_id": 1305,\n      "het_job_id_set": "1305-1308",\n      "het_job_offset": 0,\n      "partition": "vultr-mi325x-torch",\n      "memory_per_node": 2062607,\n      "memory_per_cpu": null,\n      "minimum_cpus_per_node": 64,\n      "minimum_tmp_disk_per_node": 0,\n      "preempt_time": 0,\n      "pre_sus_time": 0,\n      "priority": 4294900821,\n      "profile": null,\n      "qos": "",\n      "reboot": false,\n      "required_nodes": "",\n      "requeue": true,\n      "resize_time": 0,\n      "restart_cnt": 0,\n      "resv_name": "",\n      "shared": null,\n      "show_flags": [\n        "SHOW_ALL",\n        "SHOW_DETAIL",\n        "SHOW_LOCAL"\n      ],\n      "sockets_per_board": 0,\n      "sockets_per_node": null,\n      "start_time": 0,\n      "state_description": "",\n      "state_reason": "None",\n      "standard_error": "",\n      "standard_input": "\\/dev\\/null",\n      "standard_output": "",\n      "submit_time": 1759434814,\n      "suspend_time": 0,\n      "system_comment": "",\n      "time_limit": null,\n      "time_minimum": 0,\n      "threads_per_core": null,\n      "tres_bind": "",\n      "tres_freq": "",\n      "tres_per_job": "",\n      "tres_per_node": "gres:gpu:8",\n      "tres_per_socket": "",\n      "tres_per_task": "",\n      "tres_req_str": "cpu=64,mem=2062607M,node=1,billing=64",\n      "tres_alloc_str": "",\n      "user_id": 0,\n      "user_name": "",\n      "wckey": "",\n      "current_working_directory": "\\/mnt\\/models\\/mreso\\/monarch\\/examples"\n    },\n    {\n      "account": "",\n      "accrue_time": 0,\n      "admin_comment": "",\n      "array_job_id": 0,\n      "array_task_id": null,\n      "array_max_tasks": 0,\n      "array_task_string": "",\n      "association_id": 0,\n      "batch_features": "",\n      "batch_flag": true,\n      "batch_host": "",\n      "flags": [\n        "JOB_CPU ...
# jobs=[{'account': '', 'accrue_time': 0, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': '', 'flags': ['JOB_CPUS_SET ', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp4qc5mee9/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': None, 'cpus_per_task': None, 'cpu_frequency_minimum': None, 'cpu_frequency_maximum': None, 'cpu_frequency_governor': None, 'cpus_per_tres': '', 'deadline': 0, 'delay_boot': 0, 'dependency': '', 'derived_exit_code': 0, 'eligible_time': 1759434814, 'end_time': 0, 'excluded_nodes': '', 'exit_code': 0, 'features': '', 'federation_origin': '', 'federation_siblings_active': '', 'federation_siblings_viable': '', 'gres_detail': [], 'group_id': 0, 'job_id': 1305, 'job_resources': {}, 'job_state': 'PENDING', 'last_sched_evaluation': 1759434814, 'licenses': '', 'max_cpus': 0, 'max_nodes': 0, 'mcs_label': '', 'memory_per_tres': '', 'name': 'mesh0-0', 'nodes': '', 'nice': None, 'tasks_per_core': None, 'tasks_per_node': 1, 'tasks_per_socket': None, 'tasks_per_board': 0, 'cpus': 64, 'node_count': 1, 'tasks': 1, 'het_job_id': 1305, 'het_job_id_set': '1305-1308', 'het_job_offset': 0, 'partition': 'vultr-mi325x-torch', 'memory_per_node': 2062607, 'memory_per_cpu': None, 'minimum_cpus_per_node': 64, 'minimum_tmp_disk_per_node': 0, 'preempt_time': 0, 'pre_sus_time': 0, 'priority': 4294900821, 'profile': None, 'qos': '', 'reboot': False, 'required_nodes': '', 'requeue': True, 'resize_time': 0, 'restart_cnt': 0, 'resv_name': '', 'shared': None, 'show_flags': ['SHOW_ALL', 'SHOW_DETAIL', 'SHOW_LOCAL'], 'sockets_per_board': 0, 'sockets_per_node': None, 'start_time': 0, 'state_description': '', 'state_reason': 'None', 'standard_error': '', 'standard_input': '/dev/null', 'standard_output': '', 'submit_time': 1759434814, 'suspend_time': 0, 'system_comment': '', 'time_limit': None, 'time_minimum': 0, 'threads_per_core': None, 'tres_bind': '', 'tres_freq': '', 'tres_per_job': '', 'tres_per_node': 'gres:gpu:8', 'tres_per_socket': '', 'tres_per_task': '', 'tres_req_str': 'cpu=64,mem=2062607M,node=1,billing=64', 'tres_alloc_str': '', 'user_id': 0, 'user_name': '', 'wckey': '', 'current_working_directory': '/mnt/models/mreso/monarch/examples'}, {'account': '', 'accrue_time': 0, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': '', 'flags': ['JOB_CPUS_SET ', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp4qc5mee9/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': None, 'cpus_per_task': None, 'cpu_frequency_minimum': None, 'cpu_frequency_maximum': None, 'cpu_frequency_governor': None, 'cpus_per_tres': '', 'deadline': 0, 'delay_boot': 0, 'dependency': '', 'derived_exit_code': 0, 'eligible_time': 1759434814, 'end_time': 0, 'excluded_nodes': '', 'exit_code': 0, 'features': '', 'federation_origin': '', 'federation_siblings_active': '', 'federation_siblings_viable': '', 'gres_detail': [], 'group_id': 0, 'job_id': 1306, 'job_resources': {}, 'job_state': 'PENDING', 'last_sched_evaluation': 1759434814, 'licenses': '', 'max_cpus': 0, 'max_nodes': 0, 'mcs_label': '', 'memory_per_tres': '', 'name': 'mesh0-1', 'nodes': '', 'nice': None, 'tasks_per_core': None, 'tasks_per_node': 1, 'tasks_per_socket': None, 'tasks_per_board': 0, 'cpus': 64, 'node_count': 1, 'tasks': 1, 'het_job_id': 1305, 'het_job_id_set': '1305-1308', 'het_job_offset': 1, 'partition': 'vultr-mi325x-torch', 'memory_per_node': 2062607, 'memory_per_cpu': None, 'minim ...
# job["job_state"]='PENDING'
# state=PENDING (2)
# job["job_state"]='PENDING'
# state=PENDING (2)
# job["job_state"]='PENDING'
# state=PENDING (2)
# job["job_state"]='PENDING'
# state=PENDING (2)
# app_id='1305'lurm:///1305 to be RUNNING (current: PENDING); will check again in 5.0 seconds. Total wait time: 0:00:00.025341
# output='{\n  "meta": {\n    "plugin": {\n      "type": "openapi\\/v0.0.37",\n      "name": "Slurm OpenAPI v0.0.37"\n    },\n    "Slurm": {\n      "version": {\n        "major": 21,\n        "micro": 5,\n        "minor": 8\n      },\n      "release": "21.08.5"\n    }\n  },\n  "errors": [\n  ],\n  "jobs": [\n    {\n      "account": "",\n      "accrue_time": 1759434814,\n      "admin_comment": "",\n      "array_job_id": 0,\n      "array_task_id": null,\n      "array_max_tasks": 0,\n      "array_task_string": "",\n      "association_id": 0,\n      "batch_features": "",\n      "batch_flag": true,\n      "batch_host": "chi2599",\n      "flags": [\n        "JOB_CPUS_SET ",\n        "JOB_WAS_RUNNING",\n        "JOB_MEM_SET"\n      ],\n      "burst_buffer": "",\n      "burst_buffer_state": "",\n      "cluster": "vultr-mi325x-torch",\n      "cluster_features": "",\n      "command": "\\/tmp\\/tmp4qc5mee9\\/torchx-sbatch.sh",\n      "comment": "",\n      "contiguous": false,\n      "core_spec": null,\n      "thread_spec": null,\n      "cores_per_socket": null,\n      "billable_tres": 64.0,\n      "cpus_per_task": null,\n      "cpu_frequency_minimum": null,\n      "cpu_frequency_maximum": null,\n      "cpu_frequency_governor": null,\n      "cpus_per_tres": "",\n      "deadline": 0,\n      "delay_boot": 0,\n      "dependency": "",\n      "derived_exit_code": 0,\n      "eligible_time": 1759434814,\n      "end_time": 1790970819,\n      "excluded_nodes": "",\n      "exit_code": 0,\n      "features": "",\n      "federation_origin": "",\n      "federation_siblings_active": "",\n      "federation_siblings_viable": "",\n      "gres_detail": [\n        "gpu:AMD_Instinct_MI325X:8(IDX:0-7)"\n      ],\n      "group_id": 0,\n      "job_id": 1305,\n      "job_resources": {\n        "nodes": "chi2599",\n        "allocated_cpus": 64,\n        "allocated_hosts": 1,\n        "allocated_nodes": {\n          "0": {\n            "sockets": {\n              "0": "unassigned"\n            },\n            "cores": {\n              "0": "unassigned",\n              "1": "unassigned",\n              "2": "unassigned",\n              "3": "unassigned",\n              "4": "unassigned",\n              "5": "unassigned",\n              "6": "unassigned",\n              "7": "unassigned",\n              "8": "unassigned",\n              "9": "unassigned",\n              "10": "unassigned",\n              "11": "unassigned",\n              "12": "unassigned",\n              "13": "unassigned",\n              "14": "unassigned",\n              "15": "unassigned",\n              "16": "unassigned",\n              "17": "unassigned",\n              "18": "unassigned",\n              "19": "unassigned",\n              "20": "unassigned",\n              "21": "unassigned",\n              "22": "unassigned",\n              "23": "unassigned",\n              "24": "unassigned",\n              "25": "unassigned",\n              "26": "unassigned",\n              "27": "unassigned",\n              "28": "unassigned",\n              "29": "unassigned",\n              "30": "unassigned",\n              "31": "unassigned"\n            },\n            "memory": 2062607,\n            "cpus": 64\n          }\n        }\n      },\n      "job_state": "RUNNING",\n      "last_sched_evaluation": 1759434819,\n      "licenses": "",\n      "max_cpus": 0,\n      "max_nodes": 0,\n      "mcs_label": "",\n      "memory_per_tres": "",\n      "name": "mesh0-0",\n      "nodes": "chi2599",\n      "nice": null,\n      "tasks_per_core": null,\n      "tasks_per_node": 1,\n      "tasks_per_socket": null,\n      "tasks_per_board": 0,\n      "cpus": 64,\n      "node_count": 1,\n      "tasks": 1,\n      "het_job_id": 1305,\n      "het_job_id_set": "1305-1308",\n      "het_job_offset": 0,\n      "partition": "vultr-mi325x-torch",\n      "memory_per_node": 2062607,\n      "memory_per_cpu": null,\n      "minimum_cpus_per_node": 64,\n      "minimum_tmp_disk_per_node": 0,\n      "preempt_time": 0,\n      "pre_su ...
# jobs=[{'account': '', 'accrue_time': 1759434814, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2599', 'flags': ['JOB_CPUS_SET ', 'JOB_WAS_RUNNING', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp4qc5mee9/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 64.0, 'cpus_per_task': None, 'cpu_frequency_minimum': None, 'cpu_frequency_maximum': None, 'cpu_frequency_governor': None, 'cpus_per_tres': '', 'deadline': 0, 'delay_boot': 0, 'dependency': '', 'derived_exit_code': 0, 'eligible_time': 1759434814, 'end_time': 1790970819, 'excluded_nodes': '', 'exit_code': 0, 'features': '', 'federation_origin': '', 'federation_siblings_active': '', 'federation_siblings_viable': '', 'gres_detail': ['gpu:AMD_Instinct_MI325X:8(IDX:0-7)'], 'group_id': 0, 'job_id': 1305, 'job_resources': {'nodes': 'chi2599', 'allocated_cpus': 64, 'allocated_hosts': 1, 'allocated_nodes': {'0': {'sockets': {'0': 'unassigned'}, 'cores': {'0': 'unassigned', '1': 'unassigned', '2': 'unassigned', '3': 'unassigned', '4': 'unassigned', '5': 'unassigned', '6': 'unassigned', '7': 'unassigned', '8': 'unassigned', '9': 'unassigned', '10': 'unassigned', '11': 'unassigned', '12': 'unassigned', '13': 'unassigned', '14': 'unassigned', '15': 'unassigned', '16': 'unassigned', '17': 'unassigned', '18': 'unassigned', '19': 'unassigned', '20': 'unassigned', '21': 'unassigned', '22': 'unassigned', '23': 'unassigned', '24': 'unassigned', '25': 'unassigned', '26': 'unassigned', '27': 'unassigned', '28': 'unassigned', '29': 'unassigned', '30': 'unassigned', '31': 'unassigned'}, 'memory': 2062607, 'cpus': 64}}}, 'job_state': 'RUNNING', 'last_sched_evaluation': 1759434819, 'licenses': '', 'max_cpus': 0, 'max_nodes': 0, 'mcs_label': '', 'memory_per_tres': '', 'name': 'mesh0-0', 'nodes': 'chi2599', 'nice': None, 'tasks_per_core': None, 'tasks_per_node': 1, 'tasks_per_socket': None, 'tasks_per_board': 0, 'cpus': 64, 'node_count': 1, 'tasks': 1, 'het_job_id': 1305, 'het_job_id_set': '1305-1308', 'het_job_offset': 0, 'partition': 'vultr-mi325x-torch', 'memory_per_node': 2062607, 'memory_per_cpu': None, 'minimum_cpus_per_node': 64, 'minimum_tmp_disk_per_node': 0, 'preempt_time': 0, 'pre_sus_time': 0, 'priority': 4294900821, 'profile': None, 'qos': '', 'reboot': False, 'required_nodes': '', 'requeue': True, 'resize_time': 0, 'restart_cnt': 0, 'resv_name': '', 'shared': None, 'show_flags': ['SHOW_ALL', 'SHOW_DETAIL', 'SHOW_LOCAL'], 'sockets_per_board': 0, 'sockets_per_node': None, 'start_time': 1759434819, 'state_description': '', 'state_reason': 'None', 'standard_error': '', 'standard_input': '/dev/null', 'standard_output': '', 'submit_time': 1759434814, 'suspend_time': 0, 'system_comment': '', 'time_limit': None, 'time_minimum': 0, 'threads_per_core': None, 'tres_bind': '', 'tres_freq': '', 'tres_per_job': '', 'tres_per_node': 'gres:gpu:8', 'tres_per_socket': '', 'tres_per_task': '', 'tres_req_str': 'cpu=64,mem=2062607M,node=1,billing=64', 'tres_alloc_str': 'cpu=64,mem=2062607M,node=1,billing=64', 'user_id': 0, 'user_name': '', 'wckey': '', 'current_working_directory': '/mnt/models/mreso/monarch/examples'}, {'account': '', 'accrue_time': 1759434814, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2600', 'flags': ['JOB_CPUS_SET ', 'JOB_WAS_RUNNING', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp4qc5mee9/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 64.0, 'cpus ...
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# app_id='1305'
# output='{\n  "meta": {\n    "plugin": {\n      "type": "openapi\\/v0.0.37",\n      "name": "Slurm OpenAPI v0.0.37"\n    },\n    "Slurm": {\n      "version": {\n        "major": 21,\n        "micro": 5,\n        "minor": 8\n      },\n      "release": "21.08.5"\n    }\n  },\n  "errors": [\n  ],\n  "jobs": [\n    {\n      "account": "",\n      "accrue_time": 1759434814,\n      "admin_comment": "",\n      "array_job_id": 0,\n      "array_task_id": null,\n      "array_max_tasks": 0,\n      "array_task_string": "",\n      "association_id": 0,\n      "batch_features": "",\n      "batch_flag": true,\n      "batch_host": "chi2599",\n      "flags": [\n        "JOB_CPUS_SET ",\n        "JOB_WAS_RUNNING",\n        "JOB_MEM_SET"\n      ],\n      "burst_buffer": "",\n      "burst_buffer_state": "",\n      "cluster": "vultr-mi325x-torch",\n      "cluster_features": "",\n      "command": "\\/tmp\\/tmp4qc5mee9\\/torchx-sbatch.sh",\n      "comment": "",\n      "contiguous": false,\n      "core_spec": null,\n      "thread_spec": null,\n      "cores_per_socket": null,\n      "billable_tres": 64.0,\n      "cpus_per_task": null,\n      "cpu_frequency_minimum": null,\n      "cpu_frequency_maximum": null,\n      "cpu_frequency_governor": null,\n      "cpus_per_tres": "",\n      "deadline": 0,\n      "delay_boot": 0,\n      "dependency": "",\n      "derived_exit_code": 0,\n      "eligible_time": 1759434814,\n      "end_time": 1790970819,\n      "excluded_nodes": "",\n      "exit_code": 0,\n      "features": "",\n      "federation_origin": "",\n      "federation_siblings_active": "",\n      "federation_siblings_viable": "",\n      "gres_detail": [\n        "gpu:AMD_Instinct_MI325X:8(IDX:0-7)"\n      ],\n      "group_id": 0,\n      "job_id": 1305,\n      "job_resources": {\n        "nodes": "chi2599",\n        "allocated_cpus": 64,\n        "allocated_hosts": 1,\n        "allocated_nodes": {\n          "0": {\n            "sockets": {\n              "0": "unassigned"\n            },\n            "cores": {\n              "0": "unassigned",\n              "1": "unassigned",\n              "2": "unassigned",\n              "3": "unassigned",\n              "4": "unassigned",\n              "5": "unassigned",\n              "6": "unassigned",\n              "7": "unassigned",\n              "8": "unassigned",\n              "9": "unassigned",\n              "10": "unassigned",\n              "11": "unassigned",\n              "12": "unassigned",\n              "13": "unassigned",\n              "14": "unassigned",\n              "15": "unassigned",\n              "16": "unassigned",\n              "17": "unassigned",\n              "18": "unassigned",\n              "19": "unassigned",\n              "20": "unassigned",\n              "21": "unassigned",\n              "22": "unassigned",\n              "23": "unassigned",\n              "24": "unassigned",\n              "25": "unassigned",\n              "26": "unassigned",\n              "27": "unassigned",\n              "28": "unassigned",\n              "29": "unassigned",\n              "30": "unassigned",\n              "31": "unassigned"\n            },\n            "memory": 2062607,\n            "cpus": 64\n          }\n        }\n      },\n      "job_state": "RUNNING",\n      "last_sched_evaluation": 1759434819,\n      "licenses": "",\n      "max_cpus": 0,\n      "max_nodes": 0,\n      "mcs_label": "",\n      "memory_per_tres": "",\n      "name": "mesh0-0",\n      "nodes": "chi2599",\n      "nice": null,\n      "tasks_per_core": null,\n      "tasks_per_node": 1,\n      "tasks_per_socket": null,\n      "tasks_per_board": 0,\n      "cpus": 64,\n      "node_count": 1,\n      "tasks": 1,\n      "het_job_id": 1305,\n      "het_job_id_set": "1305-1308",\n      "het_job_offset": 0,\n      "partition": "vultr-mi325x-torch",\n      "memory_per_node": 2062607,\n      "memory_per_cpu": null,\n      "minimum_cpus_per_node": 64,\n      "minimum_tmp_disk_per_node": 0,\n      "preempt_time": 0,\n      "pre_su ...
# jobs=[{'account': '', 'accrue_time': 1759434814, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2599', 'flags': ['JOB_CPUS_SET ', 'JOB_WAS_RUNNING', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp4qc5mee9/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 64.0, 'cpus_per_task': None, 'cpu_frequency_minimum': None, 'cpu_frequency_maximum': None, 'cpu_frequency_governor': None, 'cpus_per_tres': '', 'deadline': 0, 'delay_boot': 0, 'dependency': '', 'derived_exit_code': 0, 'eligible_time': 1759434814, 'end_time': 1790970819, 'excluded_nodes': '', 'exit_code': 0, 'features': '', 'federation_origin': '', 'federation_siblings_active': '', 'federation_siblings_viable': '', 'gres_detail': ['gpu:AMD_Instinct_MI325X:8(IDX:0-7)'], 'group_id': 0, 'job_id': 1305, 'job_resources': {'nodes': 'chi2599', 'allocated_cpus': 64, 'allocated_hosts': 1, 'allocated_nodes': {'0': {'sockets': {'0': 'unassigned'}, 'cores': {'0': 'unassigned', '1': 'unassigned', '2': 'unassigned', '3': 'unassigned', '4': 'unassigned', '5': 'unassigned', '6': 'unassigned', '7': 'unassigned', '8': 'unassigned', '9': 'unassigned', '10': 'unassigned', '11': 'unassigned', '12': 'unassigned', '13': 'unassigned', '14': 'unassigned', '15': 'unassigned', '16': 'unassigned', '17': 'unassigned', '18': 'unassigned', '19': 'unassigned', '20': 'unassigned', '21': 'unassigned', '22': 'unassigned', '23': 'unassigned', '24': 'unassigned', '25': 'unassigned', '26': 'unassigned', '27': 'unassigned', '28': 'unassigned', '29': 'unassigned', '30': 'unassigned', '31': 'unassigned'}, 'memory': 2062607, 'cpus': 64}}}, 'job_state': 'RUNNING', 'last_sched_evaluation': 1759434819, 'licenses': '', 'max_cpus': 0, 'max_nodes': 0, 'mcs_label': '', 'memory_per_tres': '', 'name': 'mesh0-0', 'nodes': 'chi2599', 'nice': None, 'tasks_per_core': None, 'tasks_per_node': 1, 'tasks_per_socket': None, 'tasks_per_board': 0, 'cpus': 64, 'node_count': 1, 'tasks': 1, 'het_job_id': 1305, 'het_job_id_set': '1305-1308', 'het_job_offset': 0, 'partition': 'vultr-mi325x-torch', 'memory_per_node': 2062607, 'memory_per_cpu': None, 'minimum_cpus_per_node': 64, 'minimum_tmp_disk_per_node': 0, 'preempt_time': 0, 'pre_sus_time': 0, 'priority': 4294900821, 'profile': None, 'qos': '', 'reboot': False, 'required_nodes': '', 'requeue': True, 'resize_time': 0, 'restart_cnt': 0, 'resv_name': '', 'shared': None, 'show_flags': ['SHOW_ALL', 'SHOW_DETAIL', 'SHOW_LOCAL'], 'sockets_per_board': 0, 'sockets_per_node': None, 'start_time': 1759434819, 'state_description': '', 'state_reason': 'None', 'standard_error': '', 'standard_input': '/dev/null', 'standard_output': '', 'submit_time': 1759434814, 'suspend_time': 0, 'system_comment': '', 'time_limit': None, 'time_minimum': 0, 'threads_per_core': None, 'tres_bind': '', 'tres_freq': '', 'tres_per_job': '', 'tres_per_node': 'gres:gpu:8', 'tres_per_socket': '', 'tres_per_task': '', 'tres_req_str': 'cpu=64,mem=2062607M,node=1,billing=64', 'tres_alloc_str': 'cpu=64,mem=2062607M,node=1,billing=64', 'user_id': 0, 'user_name': '', 'wckey': '', 'current_working_directory': '/mnt/models/mreso/monarch/examples'}, {'account': '', 'accrue_time': 1759434814, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2600', 'flags': ['JOB_CPUS_SET ', 'JOB_WAS_RUNNING', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp4qc5mee9/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 64.0, 'cpus ...
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# New job `slurm:///1305` is ready to serve.

# %% [markdown]
# ### 2. Define your Titan and cluster parameters

# %%
# (c) Meta Platforms, Inc. and affiliates. Confidential and proprietary.

from torchtitan.train import Trainer
from torchtitan.config import ConfigManager, JobConfig
from monarch.actor import Actor, current_rank, endpoint
from torchtitan.tools.logging import init_logger, logger
import torch
from dataclasses import dataclass
import os
from monarch.tools import commands
from monarch.utils import setup_env_for_distributed


@dataclass
class RunParams:
    """
        Parameters for your cluster and training job, adjust as needed
    """
    training_steps: int = 50
    # model_config = "/mnt/models/mreso/torchtitan/torchtitan/models/llama3/train_configs/debug_model.toml"
    model_config = "/mnt/models/mreso/torchtitan/torchtitan/models/llama3/train_configs/llama3_8b.toml"
    # model_config = "/mnt/models/mreso/torchtitan/torchtitan/models/llama3/train_configs/llama3_70b.toml"
    dataset = "c4"
    num_nodes = num_nodes
    gpus_per_node = 8


class TrainerActor(Actor):
    """
        A simple wrapper class with executes a TorchTitan trainer in a Monarch actor
    """
    def __init__(self, job_config: JobConfig) -> None:
        self.job_config = job_config
        rank = current_rank().rank
        self.uid = f"[trainer_{rank}]"

    @endpoint
    async def start_training(self) -> None:
        init_logger()
        trainer: Trainer | None = None

        try:
            trainer = Trainer(self.job_config)
            logger.info(f"{self.uid} initialized successfully and starting training")
            trainer.train()
        except Exception:
            if trainer:
                trainer.close()
            raise
        else:
            trainer.close()
        finally:
            torch.distributed.destroy_process_group()
            logger.info(f"{self.uid} trainer cleaned up")

def make_job_config() -> JobConfig:
    """
        Create a job config which is digested by TorchTitan, sourced from RunParams
    """
    data_parallel_shard_degree = RunParams.num_nodes * RunParams.gpus_per_node
    output_path = "./outputs"

    script_dir = globals()['_dh'][0]
    default_args = [
        "--job.config_file",
        os.path.join(script_dir, RunParams.model_config),
        "--model.tokenizer_path",
        # "/mnt/models/mreso/torchtitan/tests/assets/tokenizer/",
        "/mnt/models/mreso/torchtitan/assets/hf/Llama-3.1-8B/",
        # "/mnt/models/mreso/torchtitan/assets/hf/Llama-3.1-70B/",
        "--comm.trace_buf_size",
        "0",
        "--metrics.log_freq",
        "1",
        "--parallelism.data_parallel_shard_degree",
        str(-1),
        "--activation_checkpoint.mode",
        "full",
        "--comm.train_timeout_seconds",
        "60",
        "--training.steps",
        str(RunParams.training_steps),
        "--training.dataset",
        RunParams.dataset,
        "--job.dump_folder",
        output_path,
        "--metrics.enable_tensorboard",
    ]

    config_manager = ConfigManager()
    job_config = config_manager.parse_args(default_args)

    return job_config

# %% [markdown]
# ### 3. Execute your training job
# You can make adjustments and run this on the existing SLURM allocations as many times as you would like!

# %%
# (c) Meta Platforms, Inc. and affiliates. Confidential and proprietary.

async def main():
    job_config = make_job_config()
    proc_mesh = None

    try:
        # 1. Create a proc mesh on your SLURM allocation
        print("CREATING PROC MESH")
        proc_mesh = await create_proc_mesh(RunParams.num_nodes, appdef, server_info)
        
        # 2. Define remote logging behavior
        await proc_mesh.logging_option(
            stream_to_client=True,
            aggregate_window_sec=None
        )
        # 3. Prepare trainer for torch distributed
        print("SETUP ENV FOR DISTRIBUTED")
        await setup_env_for_distributed(proc_mesh)
        
        print("SPAWNING TRAINER")
        trainer = await proc_mesh.spawn("trainer_actor", TrainerActor, job_config)
        # 4. Execute the taining job
        print("CALLING TRAINER")
        await trainer.start_training.call()
    except Exception as e:
        logger.info(f"Trainer failed: {e}")
    finally:
        if proc_mesh:
            await proc_mesh.stop()


if __name__ == "__main__":
    await main()
# Out:
# root 2025-10-02 19:53:43 WARNING tokenizer_path is deprecated, use model.hf_assets_path instead. Setting hf_assets_path to tokenizer_path temporarily.
# slurm.utils 2025-10-02 19:53:43 INFO
# ===== Server Info =====
# {
#   "name": "1305",
#   "server_handle": "slurm:///1305",
#   "state": "RUNNING",
#   "meshes": {
#     "mesh0": {
#       "host_type": "__UNSET__",
#       "hosts": 4,
#       "gpus": -1,
#       "hostnames": [
#         "chi2599",
#         "chi2600",
#         "chi2603",
#         "chi2605"
#       ]
#     }
#   }
# }
# monarch._src.actor.allocator 2025-10-02 19:53:43 INFO no match label `procmesh.monarch.meta.com/name` specified in alloc constraints
# monarch._src.actor.allocator 2025-10-02 19:53:43 INFO found a single proc mesh `mesh0` in slurm:///1305, will allocate on it
# monarch.tools.network 2025-10-02 19:53:43 INFO no AF_INET6 address that can bind TCP sockets for `chi2599:26600` (error: [Errno -3] Temporary failure in name resolution)
# monarch.tools.network 2025-10-02 19:53:43 INFO resolved AF_INET address `108.61.203.106:26600` for `chi2599:26600`
# monarch.tools.network 2025-10-02 19:53:43 INFO no AF_INET6 address that can bind TCP sockets for `chi2600:26600` (error: [Errno -3] Temporary failure in name resolution)
# monarch.tools.network 2025-10-02 19:53:43 INFO resolved AF_INET address `45.63.68.72:26600` for `chi2600:26600`
# monarch.tools.network 2025-10-02 19:53:43 INFO no AF_INET6 address that can bind TCP sockets for `chi2603:26600` (error: [Errno -3] Temporary failure in name resolution)
# monarch.tools.network 2025-10-02 19:53:43 INFO resolved AF_INET address `66.42.126.174:26600` for `chi2603:26600`
# monarch.tools.network 2025-10-02 19:53:43 INFO no AF_INET6 address that can bind TCP sockets for `chi2605:26600` (error: [Errno -3] Temporary failure in name resolution)
# monarch.tools.network 2025-10-02 19:53:43 INFO resolved AF_INET address `45.63.75.210:26600` for `chi2605:26600`
# monarch._src.actor.allocator 2025-10-02 19:53:43 INFO initializing alloc on remote allocator addresses: ['tcp!108.61.203.106:26600', 'tcp!45.63.68.72:26600', 'tcp!66.42.126.174:26600', 'tcp!45.63.75.210:26600']
# monarch._src.actor.allocator 2025-10-02 19:53:43 INFO no match label `procmesh.monarch.meta.com/name` specified in alloc constraints
# monarch._src.actor.allocator 2025-10-02 19:53:43 INFO found a single proc mesh `mesh0` in slurm:///1305, will allocate on it
# monarch.tools.network 2025-10-02 19:53:43 INFO no AF_INET6 address that can bind TCP sockets for `chi2599:26600` (error: [Errno -3] Temporary failure in name resolution)
# monarch.tools.network 2025-10-02 19:53:43 INFO resolved AF_INET address `108.61.203.106:26600` for `chi2599:26600`
# monarch.tools.network 2025-10-02 19:53:43 INFO no AF_INET6 address that can bind TCP sockets for `chi2600:26600` (error: [Errno -3] Temporary failure in name resolution)
# monarch.tools.network 2025-10-02 19:53:43 INFO resolved AF_INET address `45.63.68.72:26600` for `chi2600:26600`
# monarch.tools.network 2025-10-02 19:53:43 INFO no AF_INET6 address that can bind TCP sockets for `chi2603:26600` (error: [Errno -3] Temporary failure in name resolution)
# monarch.tools.network 2025-10-02 19:53:43 INFO resolved AF_INET address `66.42.126.174:26600` for `chi2603:26600`
# monarch.tools.network 2025-10-02 19:53:43 INFO no AF_INET6 address that can bind TCP sockets for `chi2605:26600` (error: [Errno -3] Temporary failure in name resolution)
# monarch.tools.network 2025-10-02 19:53:43 INFO resolved AF_INET address `45.63.75.210:26600` for `chi2605:26600`
# monarch._src.actor.allocator 2025-10-02 19:53:43 INFO initializing alloc on remote allocator addresses: ['tcp!108.61.203.106:26600', 'tcp!45.63.68.72:26600', 'tcp!66.42.126.174:26600', 'tcp!45.63.75.210:26600']
# [DEBUG] start_comm_watcher: ordered_hosts.len() = 4
# [DEBUG] start_comm_watcher: ordered_hosts = [RemoteProcessAllocHost { id: "108.61.203.106", hostname: "108.61.203.106" }, RemoteProcessAllocHost { id: "45.63.68.72", hostname: "45.63.68.72" }, RemoteProcessAllocHost { id: "66.42.126.174", hostname: "66.42.126.174" }, RemoteProcessAllocHost { id: "45.63.75.210", hostname: "45.63.75.210" }]
# [DEBUG] start_comm_watcher: host_states.len() = 4
# [DEBUG] start_comm_watcher: host_states keys = ["45.63.68.72", "66.42.126.174", "45.63.75.210", "108.61.203.106"]
# [DEBUG] start_comm_watcher: looking up host.id = "108.61.203.106"
# [DEBUG] start_comm_watcher: looking up host.id = "45.63.68.72"
# [DEBUG] start_comm_watcher: looking up host.id = "66.42.126.174"
# [DEBUG] start_comm_watcher: looking up host.id = "45.63.75.210"
# CREATING PROC MESH
# app_id='1305'
# output='{\n  "meta": {\n    "plugin": {\n      "type": "openapi\\/v0.0.37",\n      "name": "Slurm OpenAPI v0.0.37"\n    },\n    "Slurm": {\n      "version": {\n        "major": 21,\n        "micro": 5,\n        "minor": 8\n      },\n      "release": "21.08.5"\n    }\n  },\n  "errors": [\n  ],\n  "jobs": [\n    {\n      "account": "",\n      "accrue_time": 1759434814,\n      "admin_comment": "",\n      "array_job_id": 0,\n      "array_task_id": null,\n      "array_max_tasks": 0,\n      "array_task_string": "",\n      "association_id": 0,\n      "batch_features": "",\n      "batch_flag": true,\n      "batch_host": "chi2599",\n      "flags": [\n        "JOB_CPUS_SET ",\n        "JOB_WAS_RUNNING",\n        "JOB_MEM_SET"\n      ],\n      "burst_buffer": "",\n      "burst_buffer_state": "",\n      "cluster": "vultr-mi325x-torch",\n      "cluster_features": "",\n      "command": "\\/tmp\\/tmp4qc5mee9\\/torchx-sbatch.sh",\n      "comment": "",\n      "contiguous": false,\n      "core_spec": null,\n      "thread_spec": null,\n      "cores_per_socket": null,\n      "billable_tres": 64.0,\n      "cpus_per_task": null,\n      "cpu_frequency_minimum": null,\n      "cpu_frequency_maximum": null,\n      "cpu_frequency_governor": null,\n      "cpus_per_tres": "",\n      "deadline": 0,\n      "delay_boot": 0,\n      "dependency": "",\n      "derived_exit_code": 0,\n      "eligible_time": 1759434814,\n      "end_time": 1790970819,\n      "excluded_nodes": "",\n      "exit_code": 0,\n      "features": "",\n      "federation_origin": "",\n      "federation_siblings_active": "",\n      "federation_siblings_viable": "",\n      "gres_detail": [\n        "gpu:AMD_Instinct_MI325X:8(IDX:0-7)"\n      ],\n      "group_id": 0,\n      "job_id": 1305,\n      "job_resources": {\n        "nodes": "chi2599",\n        "allocated_cpus": 64,\n        "allocated_hosts": 1,\n        "allocated_nodes": {\n          "0": {\n            "sockets": {\n              "0": "unassigned"\n            },\n            "cores": {\n              "0": "unassigned",\n              "1": "unassigned",\n              "2": "unassigned",\n              "3": "unassigned",\n              "4": "unassigned",\n              "5": "unassigned",\n              "6": "unassigned",\n              "7": "unassigned",\n              "8": "unassigned",\n              "9": "unassigned",\n              "10": "unassigned",\n              "11": "unassigned",\n              "12": "unassigned",\n              "13": "unassigned",\n              "14": "unassigned",\n              "15": "unassigned",\n              "16": "unassigned",\n              "17": "unassigned",\n              "18": "unassigned",\n              "19": "unassigned",\n              "20": "unassigned",\n              "21": "unassigned",\n              "22": "unassigned",\n              "23": "unassigned",\n              "24": "unassigned",\n              "25": "unassigned",\n              "26": "unassigned",\n              "27": "unassigned",\n              "28": "unassigned",\n              "29": "unassigned",\n              "30": "unassigned",\n              "31": "unassigned"\n            },\n            "memory": 2062607,\n            "cpus": 64\n          }\n        }\n      },\n      "job_state": "RUNNING",\n      "last_sched_evaluation": 1759434819,\n      "licenses": "",\n      "max_cpus": 0,\n      "max_nodes": 0,\n      "mcs_label": "",\n      "memory_per_tres": "",\n      "name": "mesh0-0",\n      "nodes": "chi2599",\n      "nice": null,\n      "tasks_per_core": null,\n      "tasks_per_node": 1,\n      "tasks_per_socket": null,\n      "tasks_per_board": 0,\n      "cpus": 64,\n      "node_count": 1,\n      "tasks": 1,\n      "het_job_id": 1305,\n      "het_job_id_set": "1305-1308",\n      "het_job_offset": 0,\n      "partition": "vultr-mi325x-torch",\n      "memory_per_node": 2062607,\n      "memory_per_cpu": null,\n      "minimum_cpus_per_node": 64,\n      "minimum_tmp_disk_per_node": 0,\n      "preempt_time": 0,\n      "pre_su ...
# jobs=[{'account': '', 'accrue_time': 1759434814, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2599', 'flags': ['JOB_CPUS_SET ', 'JOB_WAS_RUNNING', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp4qc5mee9/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 64.0, 'cpus_per_task': None, 'cpu_frequency_minimum': None, 'cpu_frequency_maximum': None, 'cpu_frequency_governor': None, 'cpus_per_tres': '', 'deadline': 0, 'delay_boot': 0, 'dependency': '', 'derived_exit_code': 0, 'eligible_time': 1759434814, 'end_time': 1790970819, 'excluded_nodes': '', 'exit_code': 0, 'features': '', 'federation_origin': '', 'federation_siblings_active': '', 'federation_siblings_viable': '', 'gres_detail': ['gpu:AMD_Instinct_MI325X:8(IDX:0-7)'], 'group_id': 0, 'job_id': 1305, 'job_resources': {'nodes': 'chi2599', 'allocated_cpus': 64, 'allocated_hosts': 1, 'allocated_nodes': {'0': {'sockets': {'0': 'unassigned'}, 'cores': {'0': 'unassigned', '1': 'unassigned', '2': 'unassigned', '3': 'unassigned', '4': 'unassigned', '5': 'unassigned', '6': 'unassigned', '7': 'unassigned', '8': 'unassigned', '9': 'unassigned', '10': 'unassigned', '11': 'unassigned', '12': 'unassigned', '13': 'unassigned', '14': 'unassigned', '15': 'unassigned', '16': 'unassigned', '17': 'unassigned', '18': 'unassigned', '19': 'unassigned', '20': 'unassigned', '21': 'unassigned', '22': 'unassigned', '23': 'unassigned', '24': 'unassigned', '25': 'unassigned', '26': 'unassigned', '27': 'unassigned', '28': 'unassigned', '29': 'unassigned', '30': 'unassigned', '31': 'unassigned'}, 'memory': 2062607, 'cpus': 64}}}, 'job_state': 'RUNNING', 'last_sched_evaluation': 1759434819, 'licenses': '', 'max_cpus': 0, 'max_nodes': 0, 'mcs_label': '', 'memory_per_tres': '', 'name': 'mesh0-0', 'nodes': 'chi2599', 'nice': None, 'tasks_per_core': None, 'tasks_per_node': 1, 'tasks_per_socket': None, 'tasks_per_board': 0, 'cpus': 64, 'node_count': 1, 'tasks': 1, 'het_job_id': 1305, 'het_job_id_set': '1305-1308', 'het_job_offset': 0, 'partition': 'vultr-mi325x-torch', 'memory_per_node': 2062607, 'memory_per_cpu': None, 'minimum_cpus_per_node': 64, 'minimum_tmp_disk_per_node': 0, 'preempt_time': 0, 'pre_sus_time': 0, 'priority': 4294900821, 'profile': None, 'qos': '', 'reboot': False, 'required_nodes': '', 'requeue': True, 'resize_time': 0, 'restart_cnt': 0, 'resv_name': '', 'shared': None, 'show_flags': ['SHOW_ALL', 'SHOW_DETAIL', 'SHOW_LOCAL'], 'sockets_per_board': 0, 'sockets_per_node': None, 'start_time': 1759434819, 'state_description': '', 'state_reason': 'None', 'standard_error': '', 'standard_input': '/dev/null', 'standard_output': '', 'submit_time': 1759434814, 'suspend_time': 0, 'system_comment': '', 'time_limit': None, 'time_minimum': 0, 'threads_per_core': None, 'tres_bind': '', 'tres_freq': '', 'tres_per_job': '', 'tres_per_node': 'gres:gpu:8', 'tres_per_socket': '', 'tres_per_task': '', 'tres_req_str': 'cpu=64,mem=2062607M,node=1,billing=64', 'tres_alloc_str': 'cpu=64,mem=2062607M,node=1,billing=64', 'user_id': 0, 'user_name': '', 'wckey': '', 'current_working_directory': '/mnt/models/mreso/monarch/examples'}, {'account': '', 'accrue_time': 1759434814, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2600', 'flags': ['JOB_CPUS_SET ', 'JOB_WAS_RUNNING', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp4qc5mee9/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 64.0, 'cpus ...
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# app_id='1305'
# output='{\n  "meta": {\n    "plugin": {\n      "type": "openapi\\/v0.0.37",\n      "name": "Slurm OpenAPI v0.0.37"\n    },\n    "Slurm": {\n      "version": {\n        "major": 21,\n        "micro": 5,\n        "minor": 8\n      },\n      "release": "21.08.5"\n    }\n  },\n  "errors": [\n  ],\n  "jobs": [\n    {\n      "account": "",\n      "accrue_time": 1759434814,\n      "admin_comment": "",\n      "array_job_id": 0,\n      "array_task_id": null,\n      "array_max_tasks": 0,\n      "array_task_string": "",\n      "association_id": 0,\n      "batch_features": "",\n      "batch_flag": true,\n      "batch_host": "chi2599",\n      "flags": [\n        "JOB_CPUS_SET ",\n        "JOB_WAS_RUNNING",\n        "JOB_MEM_SET"\n      ],\n      "burst_buffer": "",\n      "burst_buffer_state": "",\n      "cluster": "vultr-mi325x-torch",\n      "cluster_features": "",\n      "command": "\\/tmp\\/tmp4qc5mee9\\/torchx-sbatch.sh",\n      "comment": "",\n      "contiguous": false,\n      "core_spec": null,\n      "thread_spec": null,\n      "cores_per_socket": null,\n      "billable_tres": 64.0,\n      "cpus_per_task": null,\n      "cpu_frequency_minimum": null,\n      "cpu_frequency_maximum": null,\n      "cpu_frequency_governor": null,\n      "cpus_per_tres": "",\n      "deadline": 0,\n      "delay_boot": 0,\n      "dependency": "",\n      "derived_exit_code": 0,\n      "eligible_time": 1759434814,\n      "end_time": 1790970819,\n      "excluded_nodes": "",\n      "exit_code": 0,\n      "features": "",\n      "federation_origin": "",\n      "federation_siblings_active": "",\n      "federation_siblings_viable": "",\n      "gres_detail": [\n        "gpu:AMD_Instinct_MI325X:8(IDX:0-7)"\n      ],\n      "group_id": 0,\n      "job_id": 1305,\n      "job_resources": {\n        "nodes": "chi2599",\n        "allocated_cpus": 64,\n        "allocated_hosts": 1,\n        "allocated_nodes": {\n          "0": {\n            "sockets": {\n              "0": "unassigned"\n            },\n            "cores": {\n              "0": "unassigned",\n              "1": "unassigned",\n              "2": "unassigned",\n              "3": "unassigned",\n              "4": "unassigned",\n              "5": "unassigned",\n              "6": "unassigned",\n              "7": "unassigned",\n              "8": "unassigned",\n              "9": "unassigned",\n              "10": "unassigned",\n              "11": "unassigned",\n              "12": "unassigned",\n              "13": "unassigned",\n              "14": "unassigned",\n              "15": "unassigned",\n              "16": "unassigned",\n              "17": "unassigned",\n              "18": "unassigned",\n              "19": "unassigned",\n              "20": "unassigned",\n              "21": "unassigned",\n              "22": "unassigned",\n              "23": "unassigned",\n              "24": "unassigned",\n              "25": "unassigned",\n              "26": "unassigned",\n              "27": "unassigned",\n              "28": "unassigned",\n              "29": "unassigned",\n              "30": "unassigned",\n              "31": "unassigned"\n            },\n            "memory": 2062607,\n            "cpus": 64\n          }\n        }\n      },\n      "job_state": "RUNNING",\n      "last_sched_evaluation": 1759434819,\n      "licenses": "",\n      "max_cpus": 0,\n      "max_nodes": 0,\n      "mcs_label": "",\n      "memory_per_tres": "",\n      "name": "mesh0-0",\n      "nodes": "chi2599",\n      "nice": null,\n      "tasks_per_core": null,\n      "tasks_per_node": 1,\n      "tasks_per_socket": null,\n      "tasks_per_board": 0,\n      "cpus": 64,\n      "node_count": 1,\n      "tasks": 1,\n      "het_job_id": 1305,\n      "het_job_id_set": "1305-1308",\n      "het_job_offset": 0,\n      "partition": "vultr-mi325x-torch",\n      "memory_per_node": 2062607,\n      "memory_per_cpu": null,\n      "minimum_cpus_per_node": 64,\n      "minimum_tmp_disk_per_node": 0,\n      "preempt_time": 0,\n      "pre_su ...
# jobs=[{'account': '', 'accrue_time': 1759434814, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2599', 'flags': ['JOB_CPUS_SET ', 'JOB_WAS_RUNNING', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp4qc5mee9/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 64.0, 'cpus_per_task': None, 'cpu_frequency_minimum': None, 'cpu_frequency_maximum': None, 'cpu_frequency_governor': None, 'cpus_per_tres': '', 'deadline': 0, 'delay_boot': 0, 'dependency': '', 'derived_exit_code': 0, 'eligible_time': 1759434814, 'end_time': 1790970819, 'excluded_nodes': '', 'exit_code': 0, 'features': '', 'federation_origin': '', 'federation_siblings_active': '', 'federation_siblings_viable': '', 'gres_detail': ['gpu:AMD_Instinct_MI325X:8(IDX:0-7)'], 'group_id': 0, 'job_id': 1305, 'job_resources': {'nodes': 'chi2599', 'allocated_cpus': 64, 'allocated_hosts': 1, 'allocated_nodes': {'0': {'sockets': {'0': 'unassigned'}, 'cores': {'0': 'unassigned', '1': 'unassigned', '2': 'unassigned', '3': 'unassigned', '4': 'unassigned', '5': 'unassigned', '6': 'unassigned', '7': 'unassigned', '8': 'unassigned', '9': 'unassigned', '10': 'unassigned', '11': 'unassigned', '12': 'unassigned', '13': 'unassigned', '14': 'unassigned', '15': 'unassigned', '16': 'unassigned', '17': 'unassigned', '18': 'unassigned', '19': 'unassigned', '20': 'unassigned', '21': 'unassigned', '22': 'unassigned', '23': 'unassigned', '24': 'unassigned', '25': 'unassigned', '26': 'unassigned', '27': 'unassigned', '28': 'unassigned', '29': 'unassigned', '30': 'unassigned', '31': 'unassigned'}, 'memory': 2062607, 'cpus': 64}}}, 'job_state': 'RUNNING', 'last_sched_evaluation': 1759434819, 'licenses': '', 'max_cpus': 0, 'max_nodes': 0, 'mcs_label': '', 'memory_per_tres': '', 'name': 'mesh0-0', 'nodes': 'chi2599', 'nice': None, 'tasks_per_core': None, 'tasks_per_node': 1, 'tasks_per_socket': None, 'tasks_per_board': 0, 'cpus': 64, 'node_count': 1, 'tasks': 1, 'het_job_id': 1305, 'het_job_id_set': '1305-1308', 'het_job_offset': 0, 'partition': 'vultr-mi325x-torch', 'memory_per_node': 2062607, 'memory_per_cpu': None, 'minimum_cpus_per_node': 64, 'minimum_tmp_disk_per_node': 0, 'preempt_time': 0, 'pre_sus_time': 0, 'priority': 4294900821, 'profile': None, 'qos': '', 'reboot': False, 'required_nodes': '', 'requeue': True, 'resize_time': 0, 'restart_cnt': 0, 'resv_name': '', 'shared': None, 'show_flags': ['SHOW_ALL', 'SHOW_DETAIL', 'SHOW_LOCAL'], 'sockets_per_board': 0, 'sockets_per_node': None, 'start_time': 1759434819, 'state_description': '', 'state_reason': 'None', 'standard_error': '', 'standard_input': '/dev/null', 'standard_output': '', 'submit_time': 1759434814, 'suspend_time': 0, 'system_comment': '', 'time_limit': None, 'time_minimum': 0, 'threads_per_core': None, 'tres_bind': '', 'tres_freq': '', 'tres_per_job': '', 'tres_per_node': 'gres:gpu:8', 'tres_per_socket': '', 'tres_per_task': '', 'tres_req_str': 'cpu=64,mem=2062607M,node=1,billing=64', 'tres_alloc_str': 'cpu=64,mem=2062607M,node=1,billing=64', 'user_id': 0, 'user_name': '', 'wckey': '', 'current_working_directory': '/mnt/models/mreso/monarch/examples'}, {'account': '', 'accrue_time': 1759434814, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2600', 'flags': ['JOB_CPUS_SET ', 'JOB_WAS_RUNNING', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp4qc5mee9/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 64.0, 'cpus ...
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# app_id='1305'
# output='{\n  "meta": {\n    "plugin": {\n      "type": "openapi\\/v0.0.37",\n      "name": "Slurm OpenAPI v0.0.37"\n    },\n    "Slurm": {\n      "version": {\n        "major": 21,\n        "micro": 5,\n        "minor": 8\n      },\n      "release": "21.08.5"\n    }\n  },\n  "errors": [\n  ],\n  "jobs": [\n    {\n      "account": "",\n      "accrue_time": 1759434814,\n      "admin_comment": "",\n      "array_job_id": 0,\n      "array_task_id": null,\n      "array_max_tasks": 0,\n      "array_task_string": "",\n      "association_id": 0,\n      "batch_features": "",\n      "batch_flag": true,\n      "batch_host": "chi2599",\n      "flags": [\n        "JOB_CPUS_SET ",\n        "JOB_WAS_RUNNING",\n        "JOB_MEM_SET"\n      ],\n      "burst_buffer": "",\n      "burst_buffer_state": "",\n      "cluster": "vultr-mi325x-torch",\n      "cluster_features": "",\n      "command": "\\/tmp\\/tmp4qc5mee9\\/torchx-sbatch.sh",\n      "comment": "",\n      "contiguous": false,\n      "core_spec": null,\n      "thread_spec": null,\n      "cores_per_socket": null,\n      "billable_tres": 64.0,\n      "cpus_per_task": null,\n      "cpu_frequency_minimum": null,\n      "cpu_frequency_maximum": null,\n      "cpu_frequency_governor": null,\n      "cpus_per_tres": "",\n      "deadline": 0,\n      "delay_boot": 0,\n      "dependency": "",\n      "derived_exit_code": 0,\n      "eligible_time": 1759434814,\n      "end_time": 1790970819,\n      "excluded_nodes": "",\n      "exit_code": 0,\n      "features": "",\n      "federation_origin": "",\n      "federation_siblings_active": "",\n      "federation_siblings_viable": "",\n      "gres_detail": [\n        "gpu:AMD_Instinct_MI325X:8(IDX:0-7)"\n      ],\n      "group_id": 0,\n      "job_id": 1305,\n      "job_resources": {\n        "nodes": "chi2599",\n        "allocated_cpus": 64,\n        "allocated_hosts": 1,\n        "allocated_nodes": {\n          "0": {\n            "sockets": {\n              "0": "unassigned"\n            },\n            "cores": {\n              "0": "unassigned",\n              "1": "unassigned",\n              "2": "unassigned",\n              "3": "unassigned",\n              "4": "unassigned",\n              "5": "unassigned",\n              "6": "unassigned",\n              "7": "unassigned",\n              "8": "unassigned",\n              "9": "unassigned",\n              "10": "unassigned",\n              "11": "unassigned",\n              "12": "unassigned",\n              "13": "unassigned",\n              "14": "unassigned",\n              "15": "unassigned",\n              "16": "unassigned",\n              "17": "unassigned",\n              "18": "unassigned",\n              "19": "unassigned",\n              "20": "unassigned",\n              "21": "unassigned",\n              "22": "unassigned",\n              "23": "unassigned",\n              "24": "unassigned",\n              "25": "unassigned",\n              "26": "unassigned",\n              "27": "unassigned",\n              "28": "unassigned",\n              "29": "unassigned",\n              "30": "unassigned",\n              "31": "unassigned"\n            },\n            "memory": 2062607,\n            "cpus": 64\n          }\n        }\n      },\n      "job_state": "RUNNING",\n      "last_sched_evaluation": 1759434819,\n      "licenses": "",\n      "max_cpus": 0,\n      "max_nodes": 0,\n      "mcs_label": "",\n      "memory_per_tres": "",\n      "name": "mesh0-0",\n      "nodes": "chi2599",\n      "nice": null,\n      "tasks_per_core": null,\n      "tasks_per_node": 1,\n      "tasks_per_socket": null,\n      "tasks_per_board": 0,\n      "cpus": 64,\n      "node_count": 1,\n      "tasks": 1,\n      "het_job_id": 1305,\n      "het_job_id_set": "1305-1308",\n      "het_job_offset": 0,\n      "partition": "vultr-mi325x-torch",\n      "memory_per_node": 2062607,\n      "memory_per_cpu": null,\n      "minimum_cpus_per_node": 64,\n      "minimum_tmp_disk_per_node": 0,\n      "preempt_time": 0,\n      "pre_su ...
# jobs=[{'account': '', 'accrue_time': 1759434814, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2599', 'flags': ['JOB_CPUS_SET ', 'JOB_WAS_RUNNING', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp4qc5mee9/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 64.0, 'cpus_per_task': None, 'cpu_frequency_minimum': None, 'cpu_frequency_maximum': None, 'cpu_frequency_governor': None, 'cpus_per_tres': '', 'deadline': 0, 'delay_boot': 0, 'dependency': '', 'derived_exit_code': 0, 'eligible_time': 1759434814, 'end_time': 1790970819, 'excluded_nodes': '', 'exit_code': 0, 'features': '', 'federation_origin': '', 'federation_siblings_active': '', 'federation_siblings_viable': '', 'gres_detail': ['gpu:AMD_Instinct_MI325X:8(IDX:0-7)'], 'group_id': 0, 'job_id': 1305, 'job_resources': {'nodes': 'chi2599', 'allocated_cpus': 64, 'allocated_hosts': 1, 'allocated_nodes': {'0': {'sockets': {'0': 'unassigned'}, 'cores': {'0': 'unassigned', '1': 'unassigned', '2': 'unassigned', '3': 'unassigned', '4': 'unassigned', '5': 'unassigned', '6': 'unassigned', '7': 'unassigned', '8': 'unassigned', '9': 'unassigned', '10': 'unassigned', '11': 'unassigned', '12': 'unassigned', '13': 'unassigned', '14': 'unassigned', '15': 'unassigned', '16': 'unassigned', '17': 'unassigned', '18': 'unassigned', '19': 'unassigned', '20': 'unassigned', '21': 'unassigned', '22': 'unassigned', '23': 'unassigned', '24': 'unassigned', '25': 'unassigned', '26': 'unassigned', '27': 'unassigned', '28': 'unassigned', '29': 'unassigned', '30': 'unassigned', '31': 'unassigned'}, 'memory': 2062607, 'cpus': 64}}}, 'job_state': 'RUNNING', 'last_sched_evaluation': 1759434819, 'licenses': '', 'max_cpus': 0, 'max_nodes': 0, 'mcs_label': '', 'memory_per_tres': '', 'name': 'mesh0-0', 'nodes': 'chi2599', 'nice': None, 'tasks_per_core': None, 'tasks_per_node': 1, 'tasks_per_socket': None, 'tasks_per_board': 0, 'cpus': 64, 'node_count': 1, 'tasks': 1, 'het_job_id': 1305, 'het_job_id_set': '1305-1308', 'het_job_offset': 0, 'partition': 'vultr-mi325x-torch', 'memory_per_node': 2062607, 'memory_per_cpu': None, 'minimum_cpus_per_node': 64, 'minimum_tmp_disk_per_node': 0, 'preempt_time': 0, 'pre_sus_time': 0, 'priority': 4294900821, 'profile': None, 'qos': '', 'reboot': False, 'required_nodes': '', 'requeue': True, 'resize_time': 0, 'restart_cnt': 0, 'resv_name': '', 'shared': None, 'show_flags': ['SHOW_ALL', 'SHOW_DETAIL', 'SHOW_LOCAL'], 'sockets_per_board': 0, 'sockets_per_node': None, 'start_time': 1759434819, 'state_description': '', 'state_reason': 'None', 'standard_error': '', 'standard_input': '/dev/null', 'standard_output': '', 'submit_time': 1759434814, 'suspend_time': 0, 'system_comment': '', 'time_limit': None, 'time_minimum': 0, 'threads_per_core': None, 'tres_bind': '', 'tres_freq': '', 'tres_per_job': '', 'tres_per_node': 'gres:gpu:8', 'tres_per_socket': '', 'tres_per_task': '', 'tres_req_str': 'cpu=64,mem=2062607M,node=1,billing=64', 'tres_alloc_str': 'cpu=64,mem=2062607M,node=1,billing=64', 'user_id': 0, 'user_name': '', 'wckey': '', 'current_working_directory': '/mnt/models/mreso/monarch/examples'}, {'account': '', 'accrue_time': 1759434814, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2600', 'flags': ['JOB_CPUS_SET ', 'JOB_WAS_RUNNING', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp4qc5mee9/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 64.0, 'cpus ...
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# app_id='1305'
# output='{\n  "meta": {\n    "plugin": {\n      "type": "openapi\\/v0.0.37",\n      "name": "Slurm OpenAPI v0.0.37"\n    },\n    "Slurm": {\n      "version": {\n        "major": 21,\n        "micro": 5,\n        "minor": 8\n      },\n      "release": "21.08.5"\n    }\n  },\n  "errors": [\n  ],\n  "jobs": [\n    {\n      "account": "",\n      "accrue_time": 1759434814,\n      "admin_comment": "",\n      "array_job_id": 0,\n      "array_task_id": null,\n      "array_max_tasks": 0,\n      "array_task_string": "",\n      "association_id": 0,\n      "batch_features": "",\n      "batch_flag": true,\n      "batch_host": "chi2599",\n      "flags": [\n        "JOB_CPUS_SET ",\n        "JOB_WAS_RUNNING",\n        "JOB_MEM_SET"\n      ],\n      "burst_buffer": "",\n      "burst_buffer_state": "",\n      "cluster": "vultr-mi325x-torch",\n      "cluster_features": "",\n      "command": "\\/tmp\\/tmp4qc5mee9\\/torchx-sbatch.sh",\n      "comment": "",\n      "contiguous": false,\n      "core_spec": null,\n      "thread_spec": null,\n      "cores_per_socket": null,\n      "billable_tres": 64.0,\n      "cpus_per_task": null,\n      "cpu_frequency_minimum": null,\n      "cpu_frequency_maximum": null,\n      "cpu_frequency_governor": null,\n      "cpus_per_tres": "",\n      "deadline": 0,\n      "delay_boot": 0,\n      "dependency": "",\n      "derived_exit_code": 0,\n      "eligible_time": 1759434814,\n      "end_time": 1790970819,\n      "excluded_nodes": "",\n      "exit_code": 0,\n      "features": "",\n      "federation_origin": "",\n      "federation_siblings_active": "",\n      "federation_siblings_viable": "",\n      "gres_detail": [\n        "gpu:AMD_Instinct_MI325X:8(IDX:0-7)"\n      ],\n      "group_id": 0,\n      "job_id": 1305,\n      "job_resources": {\n        "nodes": "chi2599",\n        "allocated_cpus": 64,\n        "allocated_hosts": 1,\n        "allocated_nodes": {\n          "0": {\n            "sockets": {\n              "0": "unassigned"\n            },\n            "cores": {\n              "0": "unassigned",\n              "1": "unassigned",\n              "2": "unassigned",\n              "3": "unassigned",\n              "4": "unassigned",\n              "5": "unassigned",\n              "6": "unassigned",\n              "7": "unassigned",\n              "8": "unassigned",\n              "9": "unassigned",\n              "10": "unassigned",\n              "11": "unassigned",\n              "12": "unassigned",\n              "13": "unassigned",\n              "14": "unassigned",\n              "15": "unassigned",\n              "16": "unassigned",\n              "17": "unassigned",\n              "18": "unassigned",\n              "19": "unassigned",\n              "20": "unassigned",\n              "21": "unassigned",\n              "22": "unassigned",\n              "23": "unassigned",\n              "24": "unassigned",\n              "25": "unassigned",\n              "26": "unassigned",\n              "27": "unassigned",\n              "28": "unassigned",\n              "29": "unassigned",\n              "30": "unassigned",\n              "31": "unassigned"\n            },\n            "memory": 2062607,\n            "cpus": 64\n          }\n        }\n      },\n      "job_state": "RUNNING",\n      "last_sched_evaluation": 1759434819,\n      "licenses": "",\n      "max_cpus": 0,\n      "max_nodes": 0,\n      "mcs_label": "",\n      "memory_per_tres": "",\n      "name": "mesh0-0",\n      "nodes": "chi2599",\n      "nice": null,\n      "tasks_per_core": null,\n      "tasks_per_node": 1,\n      "tasks_per_socket": null,\n      "tasks_per_board": 0,\n      "cpus": 64,\n      "node_count": 1,\n      "tasks": 1,\n      "het_job_id": 1305,\n      "het_job_id_set": "1305-1308",\n      "het_job_offset": 0,\n      "partition": "vultr-mi325x-torch",\n      "memory_per_node": 2062607,\n      "memory_per_cpu": null,\n      "minimum_cpus_per_node": 64,\n      "minimum_tmp_disk_per_node": 0,\n      "preempt_time": 0,\n      "pre_su ...
# jobs=[{'account': '', 'accrue_time': 1759434814, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2599', 'flags': ['JOB_CPUS_SET ', 'JOB_WAS_RUNNING', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp4qc5mee9/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 64.0, 'cpus_per_task': None, 'cpu_frequency_minimum': None, 'cpu_frequency_maximum': None, 'cpu_frequency_governor': None, 'cpus_per_tres': '', 'deadline': 0, 'delay_boot': 0, 'dependency': '', 'derived_exit_code': 0, 'eligible_time': 1759434814, 'end_time': 1790970819, 'excluded_nodes': '', 'exit_code': 0, 'features': '', 'federation_origin': '', 'federation_siblings_active': '', 'federation_siblings_viable': '', 'gres_detail': ['gpu:AMD_Instinct_MI325X:8(IDX:0-7)'], 'group_id': 0, 'job_id': 1305, 'job_resources': {'nodes': 'chi2599', 'allocated_cpus': 64, 'allocated_hosts': 1, 'allocated_nodes': {'0': {'sockets': {'0': 'unassigned'}, 'cores': {'0': 'unassigned', '1': 'unassigned', '2': 'unassigned', '3': 'unassigned', '4': 'unassigned', '5': 'unassigned', '6': 'unassigned', '7': 'unassigned', '8': 'unassigned', '9': 'unassigned', '10': 'unassigned', '11': 'unassigned', '12': 'unassigned', '13': 'unassigned', '14': 'unassigned', '15': 'unassigned', '16': 'unassigned', '17': 'unassigned', '18': 'unassigned', '19': 'unassigned', '20': 'unassigned', '21': 'unassigned', '22': 'unassigned', '23': 'unassigned', '24': 'unassigned', '25': 'unassigned', '26': 'unassigned', '27': 'unassigned', '28': 'unassigned', '29': 'unassigned', '30': 'unassigned', '31': 'unassigned'}, 'memory': 2062607, 'cpus': 64}}}, 'job_state': 'RUNNING', 'last_sched_evaluation': 1759434819, 'licenses': '', 'max_cpus': 0, 'max_nodes': 0, 'mcs_label': '', 'memory_per_tres': '', 'name': 'mesh0-0', 'nodes': 'chi2599', 'nice': None, 'tasks_per_core': None, 'tasks_per_node': 1, 'tasks_per_socket': None, 'tasks_per_board': 0, 'cpus': 64, 'node_count': 1, 'tasks': 1, 'het_job_id': 1305, 'het_job_id_set': '1305-1308', 'het_job_offset': 0, 'partition': 'vultr-mi325x-torch', 'memory_per_node': 2062607, 'memory_per_cpu': None, 'minimum_cpus_per_node': 64, 'minimum_tmp_disk_per_node': 0, 'preempt_time': 0, 'pre_sus_time': 0, 'priority': 4294900821, 'profile': None, 'qos': '', 'reboot': False, 'required_nodes': '', 'requeue': True, 'resize_time': 0, 'restart_cnt': 0, 'resv_name': '', 'shared': None, 'show_flags': ['SHOW_ALL', 'SHOW_DETAIL', 'SHOW_LOCAL'], 'sockets_per_board': 0, 'sockets_per_node': None, 'start_time': 1759434819, 'state_description': '', 'state_reason': 'None', 'standard_error': '', 'standard_input': '/dev/null', 'standard_output': '', 'submit_time': 1759434814, 'suspend_time': 0, 'system_comment': '', 'time_limit': None, 'time_minimum': 0, 'threads_per_core': None, 'tres_bind': '', 'tres_freq': '', 'tres_per_job': '', 'tres_per_node': 'gres:gpu:8', 'tres_per_socket': '', 'tres_per_task': '', 'tres_req_str': 'cpu=64,mem=2062607M,node=1,billing=64', 'tres_alloc_str': 'cpu=64,mem=2062607M,node=1,billing=64', 'user_id': 0, 'user_name': '', 'wckey': '', 'current_working_directory': '/mnt/models/mreso/monarch/examples'}, {'account': '', 'accrue_time': 1759434814, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2600', 'flags': ['JOB_CPUS_SET ', 'JOB_WAS_RUNNING', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp4qc5mee9/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 64.0, 'cpus ...
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# SETUP ENV FOR DISTRIBUTED
# SPAWNING TRAINER
# CALLING TRAINER
# [chi2600 1301869] [titan] 2025-10-02 19:54:00,816 - root - INFO - Starting job: Llama 3 8B training
# [chi2600 1301863] [titan] 2025-10-02 19:54:00,821 - root - INFO - Starting job: Llama 3 8B training
# [chi2600 1301867] [titan] 2025-10-02 19:54:00,826 - root - INFO - Starting job: Llama 3 8B training
# [chi2600 1301865] [titan] 2025-10-02 19:54:00,824 - root - INFO - Starting job: Llama 3 8B training
# [chi2600 1301862] [titan] 2025-10-02 19:54:00,828 - root - INFO - Starting job: Llama 3 8B training
# [chi2600 1301866] [titan] 2025-10-02 19:54:00,832 - root - INFO - Starting job: Llama 3 8B training
# [chi2600 1301868] [titan] 2025-10-02 19:54:00,829 - root - INFO - Starting job: Llama 3 8B training
# [chi2600 1301864] [titan] 2025-10-02 19:54:00,897 - root - INFO - Starting job: Llama 3 8B training
# [chi2605 329861] [titan] 2025-10-02 19:54:01,162 - root - INFO - Starting job: Llama 3 8B training
# [chi2605 329863] [titan] 2025-10-02 19:54:01,161 - root - INFO - Starting job: Llama 3 8B training
# [chi2605 329859] [titan] 2025-10-02 19:54:01,161 - root - INFO - Starting job: Llama 3 8B training
# [chi2605 329860] [titan] 2025-10-02 19:54:01,161 - root - INFO - Starting job: Llama 3 8B training
# [chi2605 329857] [titan] 2025-10-02 19:54:01,161 - root - INFO - Starting job: Llama 3 8B training
# [chi2605 329862] [titan] 2025-10-02 19:54:01,161 - root - INFO - Starting job: Llama 3 8B training
# [chi2605 329858] [titan] 2025-10-02 19:54:01,167 - root - INFO - Starting job: Llama 3 8B training
# [chi2603 425308] [titan] 2025-10-02 19:54:01,254 - root - INFO - Starting job: Llama 3 8B training
# [chi2603 425311] [titan] 2025-10-02 19:54:01,254 - root - INFO - Starting job: Llama 3 8B training
# [chi2599 925555] [titan] 2025-10-02 19:55:49,427 - root - INFO - [trainer_3] trainer cleaned up
# [chi2599 925553] [titan] 2025-10-02 19:55:49,439 - root - INFO - [trainer_1] trainer cleaned up
# [-]E1002 19:55:53.007497 1264410 hyperactor_mesh/src/alloc/remoteprocess.rs:1094] failed to cleanup disconnected host: got channel closed event for host 45.63.68.72 which has no known state
# [-]E1002 19:55:53.104073 1264410 hyperactor_mesh/src/alloc/remoteprocess.rs:1094] failed to cleanup disconnected host: got channel closed event for host 66.42.126.174 which has no known state
# [-]E1002 19:55:53.257281 1264410 hyperactor_mesh/src/alloc/remoteprocess.rs:1094] failed to cleanup disconnected host: got channel closed event for host 108.61.203.106 which has no known state

# %% [markdown]
# ### 4. Destory the SLURM job
# Once you're done experimenting, free up the allocation

# %%
# (c) Meta Platforms, Inc. and affiliates. Confidential and proprietary.

commands.kill(f"slurm:///{server_info.name}")
# Out:
# app_id='1305'
# output='{\n  "meta": {\n    "plugin": {\n      "type": "openapi\\/v0.0.37",\n      "name": "Slurm OpenAPI v0.0.37"\n    },\n    "Slurm": {\n      "version": {\n        "major": 21,\n        "micro": 5,\n        "minor": 8\n      },\n      "release": "21.08.5"\n    }\n  },\n  "errors": [\n  ],\n  "jobs": [\n    {\n      "account": "",\n      "accrue_time": 1759434814,\n      "admin_comment": "",\n      "array_job_id": 0,\n      "array_task_id": null,\n      "array_max_tasks": 0,\n      "array_task_string": "",\n      "association_id": 0,\n      "batch_features": "",\n      "batch_flag": true,\n      "batch_host": "chi2599",\n      "flags": [\n        "JOB_CPUS_SET ",\n        "JOB_WAS_RUNNING",\n        "JOB_MEM_SET"\n      ],\n      "burst_buffer": "",\n      "burst_buffer_state": "",\n      "cluster": "vultr-mi325x-torch",\n      "cluster_features": "",\n      "command": "\\/tmp\\/tmp4qc5mee9\\/torchx-sbatch.sh",\n      "comment": "",\n      "contiguous": false,\n      "core_spec": null,\n      "thread_spec": null,\n      "cores_per_socket": null,\n      "billable_tres": 64.0,\n      "cpus_per_task": null,\n      "cpu_frequency_minimum": null,\n      "cpu_frequency_maximum": null,\n      "cpu_frequency_governor": null,\n      "cpus_per_tres": "",\n      "deadline": 0,\n      "delay_boot": 0,\n      "dependency": "",\n      "derived_exit_code": 0,\n      "eligible_time": 1759434814,\n      "end_time": 1790970819,\n      "excluded_nodes": "",\n      "exit_code": 0,\n      "features": "",\n      "federation_origin": "",\n      "federation_siblings_active": "",\n      "federation_siblings_viable": "",\n      "gres_detail": [\n        "gpu:AMD_Instinct_MI325X:8(IDX:0-7)"\n      ],\n      "group_id": 0,\n      "job_id": 1305,\n      "job_resources": {\n        "nodes": "chi2599",\n        "allocated_cpus": 64,\n        "allocated_hosts": 1,\n        "allocated_nodes": {\n          "0": {\n            "sockets": {\n              "0": "unassigned"\n            },\n            "cores": {\n              "0": "unassigned",\n              "1": "unassigned",\n              "2": "unassigned",\n              "3": "unassigned",\n              "4": "unassigned",\n              "5": "unassigned",\n              "6": "unassigned",\n              "7": "unassigned",\n              "8": "unassigned",\n              "9": "unassigned",\n              "10": "unassigned",\n              "11": "unassigned",\n              "12": "unassigned",\n              "13": "unassigned",\n              "14": "unassigned",\n              "15": "unassigned",\n              "16": "unassigned",\n              "17": "unassigned",\n              "18": "unassigned",\n              "19": "unassigned",\n              "20": "unassigned",\n              "21": "unassigned",\n              "22": "unassigned",\n              "23": "unassigned",\n              "24": "unassigned",\n              "25": "unassigned",\n              "26": "unassigned",\n              "27": "unassigned",\n              "28": "unassigned",\n              "29": "unassigned",\n              "30": "unassigned",\n              "31": "unassigned"\n            },\n            "memory": 2062607,\n            "cpus": 64\n          }\n        }\n      },\n      "job_state": "RUNNING",\n      "last_sched_evaluation": 1759434819,\n      "licenses": "",\n      "max_cpus": 0,\n      "max_nodes": 0,\n      "mcs_label": "",\n      "memory_per_tres": "",\n      "name": "mesh0-0",\n      "nodes": "chi2599",\n      "nice": null,\n      "tasks_per_core": null,\n      "tasks_per_node": 1,\n      "tasks_per_socket": null,\n      "tasks_per_board": 0,\n      "cpus": 64,\n      "node_count": 1,\n      "tasks": 1,\n      "het_job_id": 1305,\n      "het_job_id_set": "1305-1308",\n      "het_job_offset": 0,\n      "partition": "vultr-mi325x-torch",\n      "memory_per_node": 2062607,\n      "memory_per_cpu": null,\n      "minimum_cpus_per_node": 64,\n      "minimum_tmp_disk_per_node": 0,\n      "preempt_time": 0,\n      "pre_su ...
# jobs=[{'account': '', 'accrue_time': 1759434814, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2599', 'flags': ['JOB_CPUS_SET ', 'JOB_WAS_RUNNING', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp4qc5mee9/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 64.0, 'cpus_per_task': None, 'cpu_frequency_minimum': None, 'cpu_frequency_maximum': None, 'cpu_frequency_governor': None, 'cpus_per_tres': '', 'deadline': 0, 'delay_boot': 0, 'dependency': '', 'derived_exit_code': 0, 'eligible_time': 1759434814, 'end_time': 1790970819, 'excluded_nodes': '', 'exit_code': 0, 'features': '', 'federation_origin': '', 'federation_siblings_active': '', 'federation_siblings_viable': '', 'gres_detail': ['gpu:AMD_Instinct_MI325X:8(IDX:0-7)'], 'group_id': 0, 'job_id': 1305, 'job_resources': {'nodes': 'chi2599', 'allocated_cpus': 64, 'allocated_hosts': 1, 'allocated_nodes': {'0': {'sockets': {'0': 'unassigned'}, 'cores': {'0': 'unassigned', '1': 'unassigned', '2': 'unassigned', '3': 'unassigned', '4': 'unassigned', '5': 'unassigned', '6': 'unassigned', '7': 'unassigned', '8': 'unassigned', '9': 'unassigned', '10': 'unassigned', '11': 'unassigned', '12': 'unassigned', '13': 'unassigned', '14': 'unassigned', '15': 'unassigned', '16': 'unassigned', '17': 'unassigned', '18': 'unassigned', '19': 'unassigned', '20': 'unassigned', '21': 'unassigned', '22': 'unassigned', '23': 'unassigned', '24': 'unassigned', '25': 'unassigned', '26': 'unassigned', '27': 'unassigned', '28': 'unassigned', '29': 'unassigned', '30': 'unassigned', '31': 'unassigned'}, 'memory': 2062607, 'cpus': 64}}}, 'job_state': 'RUNNING', 'last_sched_evaluation': 1759434819, 'licenses': '', 'max_cpus': 0, 'max_nodes': 0, 'mcs_label': '', 'memory_per_tres': '', 'name': 'mesh0-0', 'nodes': 'chi2599', 'nice': None, 'tasks_per_core': None, 'tasks_per_node': 1, 'tasks_per_socket': None, 'tasks_per_board': 0, 'cpus': 64, 'node_count': 1, 'tasks': 1, 'het_job_id': 1305, 'het_job_id_set': '1305-1308', 'het_job_offset': 0, 'partition': 'vultr-mi325x-torch', 'memory_per_node': 2062607, 'memory_per_cpu': None, 'minimum_cpus_per_node': 64, 'minimum_tmp_disk_per_node': 0, 'preempt_time': 0, 'pre_sus_time': 0, 'priority': 4294900821, 'profile': None, 'qos': '', 'reboot': False, 'required_nodes': '', 'requeue': True, 'resize_time': 0, 'restart_cnt': 0, 'resv_name': '', 'shared': None, 'show_flags': ['SHOW_ALL', 'SHOW_DETAIL', 'SHOW_LOCAL'], 'sockets_per_board': 0, 'sockets_per_node': None, 'start_time': 1759434819, 'state_description': '', 'state_reason': 'None', 'standard_error': '', 'standard_input': '/dev/null', 'standard_output': '', 'submit_time': 1759434814, 'suspend_time': 0, 'system_comment': '', 'time_limit': None, 'time_minimum': 0, 'threads_per_core': None, 'tres_bind': '', 'tres_freq': '', 'tres_per_job': '', 'tres_per_node': 'gres:gpu:8', 'tres_per_socket': '', 'tres_per_task': '', 'tres_req_str': 'cpu=64,mem=2062607M,node=1,billing=64', 'tres_alloc_str': 'cpu=64,mem=2062607M,node=1,billing=64', 'user_id': 0, 'user_name': '', 'wckey': '', 'current_working_directory': '/mnt/models/mreso/monarch/examples'}, {'account': '', 'accrue_time': 1759434814, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2600', 'flags': ['JOB_CPUS_SET ', 'JOB_WAS_RUNNING', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp4qc5mee9/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 64.0, 'cpus ...
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# app_id='1305'
# output='{\n  "meta": {\n    "plugin": {\n      "type": "openapi\\/v0.0.37",\n      "name": "Slurm OpenAPI v0.0.37"\n    },\n    "Slurm": {\n      "version": {\n        "major": 21,\n        "micro": 5,\n        "minor": 8\n      },\n      "release": "21.08.5"\n    }\n  },\n  "errors": [\n  ],\n  "jobs": [\n    {\n      "account": "",\n      "accrue_time": 1759434814,\n      "admin_comment": "",\n      "array_job_id": 0,\n      "array_task_id": null,\n      "array_max_tasks": 0,\n      "array_task_string": "",\n      "association_id": 0,\n      "batch_features": "",\n      "batch_flag": true,\n      "batch_host": "chi2599",\n      "flags": [\n        "JOB_CPUS_SET ",\n        "JOB_WAS_RUNNING",\n        "JOB_MEM_SET"\n      ],\n      "burst_buffer": "",\n      "burst_buffer_state": "",\n      "cluster": "vultr-mi325x-torch",\n      "cluster_features": "",\n      "command": "\\/tmp\\/tmp4qc5mee9\\/torchx-sbatch.sh",\n      "comment": "",\n      "contiguous": false,\n      "core_spec": null,\n      "thread_spec": null,\n      "cores_per_socket": null,\n      "billable_tres": 64.0,\n      "cpus_per_task": null,\n      "cpu_frequency_minimum": null,\n      "cpu_frequency_maximum": null,\n      "cpu_frequency_governor": null,\n      "cpus_per_tres": "",\n      "deadline": 0,\n      "delay_boot": 0,\n      "dependency": "",\n      "derived_exit_code": 0,\n      "eligible_time": 1759434814,\n      "end_time": 1790970819,\n      "excluded_nodes": "",\n      "exit_code": 0,\n      "features": "",\n      "federation_origin": "",\n      "federation_siblings_active": "",\n      "federation_siblings_viable": "",\n      "gres_detail": [\n        "gpu:AMD_Instinct_MI325X:8(IDX:0-7)"\n      ],\n      "group_id": 0,\n      "job_id": 1305,\n      "job_resources": {\n        "nodes": "chi2599",\n        "allocated_cpus": 64,\n        "allocated_hosts": 1,\n        "allocated_nodes": {\n          "0": {\n            "sockets": {\n              "0": "unassigned"\n            },\n            "cores": {\n              "0": "unassigned",\n              "1": "unassigned",\n              "2": "unassigned",\n              "3": "unassigned",\n              "4": "unassigned",\n              "5": "unassigned",\n              "6": "unassigned",\n              "7": "unassigned",\n              "8": "unassigned",\n              "9": "unassigned",\n              "10": "unassigned",\n              "11": "unassigned",\n              "12": "unassigned",\n              "13": "unassigned",\n              "14": "unassigned",\n              "15": "unassigned",\n              "16": "unassigned",\n              "17": "unassigned",\n              "18": "unassigned",\n              "19": "unassigned",\n              "20": "unassigned",\n              "21": "unassigned",\n              "22": "unassigned",\n              "23": "unassigned",\n              "24": "unassigned",\n              "25": "unassigned",\n              "26": "unassigned",\n              "27": "unassigned",\n              "28": "unassigned",\n              "29": "unassigned",\n              "30": "unassigned",\n              "31": "unassigned"\n            },\n            "memory": 2062607,\n            "cpus": 64\n          }\n        }\n      },\n      "job_state": "RUNNING",\n      "last_sched_evaluation": 1759434819,\n      "licenses": "",\n      "max_cpus": 0,\n      "max_nodes": 0,\n      "mcs_label": "",\n      "memory_per_tres": "",\n      "name": "mesh0-0",\n      "nodes": "chi2599",\n      "nice": null,\n      "tasks_per_core": null,\n      "tasks_per_node": 1,\n      "tasks_per_socket": null,\n      "tasks_per_board": 0,\n      "cpus": 64,\n      "node_count": 1,\n      "tasks": 1,\n      "het_job_id": 1305,\n      "het_job_id_set": "1305-1308",\n      "het_job_offset": 0,\n      "partition": "vultr-mi325x-torch",\n      "memory_per_node": 2062607,\n      "memory_per_cpu": null,\n      "minimum_cpus_per_node": 64,\n      "minimum_tmp_disk_per_node": 0,\n      "preempt_time": 0,\n      "pre_su ...
# jobs=[{'account': '', 'accrue_time': 1759434814, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2599', 'flags': ['JOB_CPUS_SET ', 'JOB_WAS_RUNNING', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp4qc5mee9/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 64.0, 'cpus_per_task': None, 'cpu_frequency_minimum': None, 'cpu_frequency_maximum': None, 'cpu_frequency_governor': None, 'cpus_per_tres': '', 'deadline': 0, 'delay_boot': 0, 'dependency': '', 'derived_exit_code': 0, 'eligible_time': 1759434814, 'end_time': 1790970819, 'excluded_nodes': '', 'exit_code': 0, 'features': '', 'federation_origin': '', 'federation_siblings_active': '', 'federation_siblings_viable': '', 'gres_detail': ['gpu:AMD_Instinct_MI325X:8(IDX:0-7)'], 'group_id': 0, 'job_id': 1305, 'job_resources': {'nodes': 'chi2599', 'allocated_cpus': 64, 'allocated_hosts': 1, 'allocated_nodes': {'0': {'sockets': {'0': 'unassigned'}, 'cores': {'0': 'unassigned', '1': 'unassigned', '2': 'unassigned', '3': 'unassigned', '4': 'unassigned', '5': 'unassigned', '6': 'unassigned', '7': 'unassigned', '8': 'unassigned', '9': 'unassigned', '10': 'unassigned', '11': 'unassigned', '12': 'unassigned', '13': 'unassigned', '14': 'unassigned', '15': 'unassigned', '16': 'unassigned', '17': 'unassigned', '18': 'unassigned', '19': 'unassigned', '20': 'unassigned', '21': 'unassigned', '22': 'unassigned', '23': 'unassigned', '24': 'unassigned', '25': 'unassigned', '26': 'unassigned', '27': 'unassigned', '28': 'unassigned', '29': 'unassigned', '30': 'unassigned', '31': 'unassigned'}, 'memory': 2062607, 'cpus': 64}}}, 'job_state': 'RUNNING', 'last_sched_evaluation': 1759434819, 'licenses': '', 'max_cpus': 0, 'max_nodes': 0, 'mcs_label': '', 'memory_per_tres': '', 'name': 'mesh0-0', 'nodes': 'chi2599', 'nice': None, 'tasks_per_core': None, 'tasks_per_node': 1, 'tasks_per_socket': None, 'tasks_per_board': 0, 'cpus': 64, 'node_count': 1, 'tasks': 1, 'het_job_id': 1305, 'het_job_id_set': '1305-1308', 'het_job_offset': 0, 'partition': 'vultr-mi325x-torch', 'memory_per_node': 2062607, 'memory_per_cpu': None, 'minimum_cpus_per_node': 64, 'minimum_tmp_disk_per_node': 0, 'preempt_time': 0, 'pre_sus_time': 0, 'priority': 4294900821, 'profile': None, 'qos': '', 'reboot': False, 'required_nodes': '', 'requeue': True, 'resize_time': 0, 'restart_cnt': 0, 'resv_name': '', 'shared': None, 'show_flags': ['SHOW_ALL', 'SHOW_DETAIL', 'SHOW_LOCAL'], 'sockets_per_board': 0, 'sockets_per_node': None, 'start_time': 1759434819, 'state_description': '', 'state_reason': 'None', 'standard_error': '', 'standard_input': '/dev/null', 'standard_output': '', 'submit_time': 1759434814, 'suspend_time': 0, 'system_comment': '', 'time_limit': None, 'time_minimum': 0, 'threads_per_core': None, 'tres_bind': '', 'tres_freq': '', 'tres_per_job': '', 'tres_per_node': 'gres:gpu:8', 'tres_per_socket': '', 'tres_per_task': '', 'tres_req_str': 'cpu=64,mem=2062607M,node=1,billing=64', 'tres_alloc_str': 'cpu=64,mem=2062607M,node=1,billing=64', 'user_id': 0, 'user_name': '', 'wckey': '', 'current_working_directory': '/mnt/models/mreso/monarch/examples'}, {'account': '', 'accrue_time': 1759434814, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2600', 'flags': ['JOB_CPUS_SET ', 'JOB_WAS_RUNNING', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp4qc5mee9/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 64.0, 'cpus ...
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
