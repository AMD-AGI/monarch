# %%
# %cd /mnt/models/mreso/monarch/examples/
# Out:
# /mnt/models/mreso/monarch/examples

# %%
# (c) Meta Platforms, Inc. and affiliates. Confidential and proprietary.

# @noautodeps
# pyre-ignore-all-errors
import logging
import os
import os
import torch
import torch.distributed as dist
import torch.distributed as dist
import torch.nn as nn
import torch.optim as optim

from monarch.tools import commands
from monarch.actor import Actor, current_rank, endpoint
from monarch.actor import Actor, current_rank, endpoint
from monarch.utils import setup_env_for_distributed
from torch.nn.parallel import DistributedDataParallel as DDP
from slurm.utils import get_appdef, get_server_info, create_proc_mesh

os.environ["RUST_BACKTRACE"] = "full"
os.environ["RUST_LOG"] = "debug"


logging.basicConfig(
    level=logging.DEBUG,
    format="%(name)s %(asctime)s %(levelname)s %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
    force=True,
)


logger: logging.Logger = logging.getLogger(__name__)


class ToyModel(nn.Module):
    """A simple toy model for demonstration purposes."""

    def __init__(self):
        super(ToyModel, self).__init__()
        self.net1 = nn.Linear(10, 10000000)
        self.relu = nn.ReLU()
        self.net2 = nn.Linear(10000000, 5)

    def forward(self, x):
        return self.net2(self.relu(self.net1(x)))


class DDPActor(Actor):
    """This Actor wraps the basic functionality from Torch's DDP example.

    Conveniently, all of the methods we need are already laid out for us,
    so we can just wrap them in the usual Actor endpoint semantic with some
    light modifications.

    Adapted from: https://docs.pytorch.org/tutorials/intermediate/ddp_tutorial.html#basic-use-case
    """

    def __init__(self):
        self.rank = current_rank().rank

    def _rprint(self, msg):
        """Helper method to print with rank information."""
        print(f"{self.rank=} {msg}")

    @endpoint
    async def setup(self):
        """Initialize the PyTorch distributed process group."""
        self._rprint("Initializing torch distributed")

        WORLD_SIZE = int(os.environ["WORLD_SIZE"])
        # initialize the process group
        dist.init_process_group("gloo", rank=self.rank, world_size=WORLD_SIZE)
        self._rprint("Finished initializing torch distributed")

    @endpoint
    async def cleanup(self):
        """Clean up the PyTorch distributed process group."""
        self._rprint("Cleaning up torch distributed")
        dist.destroy_process_group()

    @endpoint
    async def demo_basic(self):
        """Run a basic DDP training example."""
        self._rprint("Running basic DDP example")

        # create model and move it to GPU with id rank
        local_rank = int(os.environ["LOCAL_RANK"])
        self._rprint(f"{local_rank=}")
        model = ToyModel().to(local_rank)
        ddp_model = DDP(model, device_ids=[local_rank])

        loss_fn = nn.MSELoss()
        optimizer = optim.SGD(ddp_model.parameters(), lr=0.001)
        for iter in range(50):
            print(f"{iter=}")

            optimizer.zero_grad()
            outputs = ddp_model(torch.randn(20, 10))
            labels = torch.randn(20, 5).to(local_rank)
            loss_fn(outputs, labels).backward()
            optimizer.step()

        print(f"{self.rank=} Finished running basic DDP example")


async def main():
    num_hosts = 2
    appdef = await get_appdef(num_hosts)
    server_info = await get_server_info(appdef)

    try:
        print("CREATE PROC MESH")
        proc_mesh = await create_proc_mesh(num_hosts, appdef, server_info)

        print("SPAWN ACTORS")
        ddp_actor = proc_mesh.spawn("ddp_actor", DDPActor)
        print("SETUP ENV")
        await setup_env_for_distributed(proc_mesh)
        print("SETUP CALL")
        await ddp_actor.setup.call()
        print("BASIC DEMO CALL")
        await ddp_actor.demo_basic.call()
        print("CLEAUP CALL")
        await ddp_actor.cleanup.call()

        print("DDP example completed successfully!")

    finally:
        commands.kill(f"slurm:///{server_info.name}")


if __name__ == "__main__":
    await main()
# Out:
# <string>:8: FutureWarning: Setting `workspace='/mnt/models/mreso/monarch/examples'` is deprecated. Use `workspace=monarch.tools.config.workspace.Workspace(dirs=['/mnt/models/mreso/monarch/examples'])` instead.
# torchx.schedulers.slurm_scheduler 2025-09-30 23:31:42 INFO unable to get job info for `monarch-root` with `squeue` (squeue: error: Invalid job id: monarch-root
# ), trying `sacct`
# torchx.schedulers.slurm_scheduler 2025-09-30 23:31:42 INFO unable to get job info for `monarch-root` with `sacct` (sacct: fatal: Bad job/step specified: monarch-root
# )
# monarch.tools.commands 2025-09-30 23:31:42 INFO no existing RUNNING server `slurm:///monarch-root` creating new one...
# torchx.runner.api 2025-09-30 23:31:42 INFO Tracker configurations: {}
# torchx.runner.api 2025-09-30 23:31:42 INFO Checking for changes in workspace `/root/.monarch/out/tmphxj0aymo/workspace`...
# torchx.runner.api 2025-09-30 23:31:42 INFO To disable workspaces pass: --workspace="" from CLI or workspace=None programmatically.
# torchx.runner.api 2025-09-30 23:31:42 INFO Reusing original image `monarch_default_workspace:latest` for role[0]=mesh0. Either a patch was built or no changes to workspace was detected.
# monarch.tools.commands 2025-09-30 23:31:42 INFO created new `slurm:///1049` waiting for it to be ready...
# app_id='monarch-root'
# slurm_24_11_0=(24, 11)
# slurm_version=(21, 8)
# slurm_24_11_0=(24, 11)
# slurm_version=(21, 8)
# script='#!/bin/bash\n#\n# Generated by TorchX 0.8.0dev0\n# Run with: sbatch --parsable /tmp/tmp34i0puj4/torchx-sbatch.sh\n#\n#SBATCH --job-name=mesh0-0 --requeue --ntasks-per-node=1 --cpus-per-task=48 --mem=186777 --gpus-per-node=4\n#SBATCH hetjob\n#SBATCH --job-name=mesh0-1 --requeue --ntasks-per-node=1 --cpus-per-task=48 --mem=186777 --gpus-per-node=4\n\nset -evx\n\nexport PYTHONUNBUFFERED=1\nexport SLURM_UNBUFFEREDIO=1\nexport TORCHX_MAX_RETRIES=0\n\nset +e\nsrun --output=slurm-"$SLURM_JOB_ID"-mesh0-0.out --error=slurm-"$SLURM_JOB_ID"-mesh0-0.err --wait=60 --kill-on-bad-exit=1 --export=ALL,WORKSPACE_DIR=monarch_default_workspace:latest/workspace,PYTHONPATH=monarch_default_workspace:latest/workspace/,CONDA_DIR=monarch_default_workspace:latest/conda,TORCHX_JOB_ID=slurm:///"$SLURM_JOB_ID",TORCHX_INTERNAL_SESSION_ID=3d5b0581-9296-4a5a-80de-f2fc9b2ad68f process_allocator --port=26600 --program=monarch_bootstrap :\\\n     --output=slurm-"$SLURM_JOB_ID"-mesh0-1.out --error=slurm-"$SLURM_JOB_ID"-mesh0-1.err --wait=60 --kill-on-bad-exit=1 --export=ALL,WORKSPACE_DIR=monarch_default_workspace:latest/workspace,PYTHONPATH=monarch_default_workspace:latest/workspace/,CONDA_DIR=monarch_default_workspace:latest/conda,TORCHX_JOB_ID=slurm:///"$SLURM_JOB_ID",TORCHX_INTERNAL_SESSION_ID=3d5b0581-9296-4a5a-80de-f2fc9b2ad68f process_allocator --port=26600 --program=monarch_bootstrap\nexitcode=$?\nset -e\n\necho "job exited with code $exitcode"\nif [ $exitcode -ne 0 ]; then\n    if [ "$TORCHX_MAX_RETRIES" -gt "${SLURM_RESTART_COUNT:-0}" ]; then\n        scontrol requeue "$SLURM_JOB_ID"\n    fi\n    exit $exitcode\nfi\n'
# req.cmd=['sbatch', '--parsable', '/tmp/tmp34i0puj4/torchx-sbatch.sh']
# app_id='1049'
# output='{\n  "meta": {\n    "plugin": {\n      "type": "openapi\\/v0.0.37",\n      "name": "Slurm OpenAPI v0.0.37"\n    },\n    "Slurm": {\n      "version": {\n        "major": 21,\n        "micro": 5,\n        "minor": 8\n      },\n      "release": "21.08.5"\n    }\n  },\n  "errors": [\n  ],\n  "jobs": [\n    {\n      "account": "",\n      "accrue_time": 1759275005,\n      "admin_comment": "",\n      "array_job_id": 0,\n      "array_task_id": null,\n      "array_max_tasks": 0,\n      "array_task_string": "",\n      "association_id": 0,\n      "batch_features": "",\n      "batch_flag": true,\n      "batch_host": "chi2599",\n      "flags": [\n        "TRES_STR_CALC",\n        "JOB_CPUS_SET ",\n        "JOB_MEM_SET"\n      ],\n      "burst_buffer": "",\n      "burst_buffer_state": "",\n      "cluster": "vultr-mi325x-torch",\n      "cluster_features": "",\n      "command": "\\/tmp\\/tmp2_4bbv4b\\/torchx-sbatch.sh",\n      "comment": "",\n      "contiguous": false,\n      "core_spec": null,\n      "thread_spec": null,\n      "cores_per_socket": null,\n      "billable_tres": 48.0,\n      "cpus_per_task": null,\n      "cpu_frequency_minimum": null,\n      "cpu_frequency_maximum": null,\n      "cpu_frequency_governor": null,\n      "cpus_per_tres": "",\n      "deadline": 0,\n      "delay_boot": 0,\n      "dependency": "",\n      "derived_exit_code": 15,\n      "eligible_time": 1759275005,\n      "end_time": 1759275047,\n      "excluded_nodes": "",\n      "exit_code": 15,\n      "features": "",\n      "federation_origin": "",\n      "federation_siblings_active": "",\n      "federation_siblings_viable": "",\n      "gres_detail": [\n      ],\n      "group_id": 0,\n      "job_id": 1046,\n      "job_resources": {\n        "nodes": "chi2599",\n        "allocated_cpus": 48,\n        "allocated_hosts": 1,\n        "allocated_nodes": {\n          "0": {\n            "sockets": {\n              "0": "unassigned"\n            },\n            "cores": {\n              "0": "unassigned",\n              "1": "unassigned",\n              "2": "unassigned",\n              "3": "unassigned",\n              "4": "unassigned",\n              "5": "unassigned",\n              "6": "unassigned",\n              "7": "unassigned",\n              "8": "unassigned",\n              "9": "unassigned",\n              "10": "unassigned",\n              "11": "unassigned",\n              "12": "unassigned",\n              "13": "unassigned",\n              "14": "unassigned",\n              "15": "unassigned",\n              "16": "unassigned",\n              "17": "unassigned",\n              "18": "unassigned",\n              "19": "unassigned",\n              "20": "unassigned",\n              "21": "unassigned",\n              "22": "unassigned",\n              "23": "unassigned"\n            },\n            "memory": 186777,\n            "cpus": 48\n          }\n        }\n      },\n      "job_state": "CANCELLED",\n      "last_sched_evaluation": 1759275005,\n      "licenses": "",\n      "max_cpus": 0,\n      "max_nodes": 0,\n      "mcs_label": "",\n      "memory_per_tres": "",\n      "name": "mesh0-0",\n      "nodes": "chi2599",\n      "nice": null,\n      "tasks_per_core": null,\n      "tasks_per_node": 1,\n      "tasks_per_socket": null,\n      "tasks_per_board": 0,\n      "cpus": 48,\n      "node_count": 1,\n      "tasks": 1,\n      "het_job_id": 1046,\n      "het_job_id_set": "1046-1047",\n      "het_job_offset": 0,\n      "partition": "vultr-mi325x-torch",\n      "memory_per_node": 186777,\n      "memory_per_cpu": null,\n      "minimum_cpus_per_node": 48,\n      "minimum_tmp_disk_per_node": 0,\n      "preempt_time": 0,\n      "pre_sus_time": 0,\n      "priority": 4294901080,\n      "profile": null,\n      "qos": "",\n      "reboot": false,\n      "required_nodes": "",\n      "requeue": true,\n      "resize_time": 0,\n      "restart_cnt": 0,\n      "resv_name": "",\n      "shared": null,\n      "show_flags": [\n        "SHOW_ALL",\n        "SHOW_DETAIL", ...
# jobs=[{'account': '', 'accrue_time': 1759275005, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2599', 'flags': ['TRES_STR_CALC', 'JOB_CPUS_SET ', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp2_4bbv4b/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 48.0, 'cpus_per_task': None, 'cpu_frequency_minimum': None, 'cpu_frequency_maximum': None, 'cpu_frequency_governor': None, 'cpus_per_tres': '', 'deadline': 0, 'delay_boot': 0, 'dependency': '', 'derived_exit_code': 15, 'eligible_time': 1759275005, 'end_time': 1759275047, 'excluded_nodes': '', 'exit_code': 15, 'features': '', 'federation_origin': '', 'federation_siblings_active': '', 'federation_siblings_viable': '', 'gres_detail': [], 'group_id': 0, 'job_id': 1046, 'job_resources': {'nodes': 'chi2599', 'allocated_cpus': 48, 'allocated_hosts': 1, 'allocated_nodes': {'0': {'sockets': {'0': 'unassigned'}, 'cores': {'0': 'unassigned', '1': 'unassigned', '2': 'unassigned', '3': 'unassigned', '4': 'unassigned', '5': 'unassigned', '6': 'unassigned', '7': 'unassigned', '8': 'unassigned', '9': 'unassigned', '10': 'unassigned', '11': 'unassigned', '12': 'unassigned', '13': 'unassigned', '14': 'unassigned', '15': 'unassigned', '16': 'unassigned', '17': 'unassigned', '18': 'unassigned', '19': 'unassigned', '20': 'unassigned', '21': 'unassigned', '22': 'unassigned', '23': 'unassigned'}, 'memory': 186777, 'cpus': 48}}}, 'job_state': 'CANCELLED', 'last_sched_evaluation': 1759275005, 'licenses': '', 'max_cpus': 0, 'max_nodes': 0, 'mcs_label': '', 'memory_per_tres': '', 'name': 'mesh0-0', 'nodes': 'chi2599', 'nice': None, 'tasks_per_core': None, 'tasks_per_node': 1, 'tasks_per_socket': None, 'tasks_per_board': 0, 'cpus': 48, 'node_count': 1, 'tasks': 1, 'het_job_id': 1046, 'het_job_id_set': '1046-1047', 'het_job_offset': 0, 'partition': 'vultr-mi325x-torch', 'memory_per_node': 186777, 'memory_per_cpu': None, 'minimum_cpus_per_node': 48, 'minimum_tmp_disk_per_node': 0, 'preempt_time': 0, 'pre_sus_time': 0, 'priority': 4294901080, 'profile': None, 'qos': '', 'reboot': False, 'required_nodes': '', 'requeue': True, 'resize_time': 0, 'restart_cnt': 0, 'resv_name': '', 'shared': None, 'show_flags': ['SHOW_ALL', 'SHOW_DETAIL', 'SHOW_LOCAL'], 'sockets_per_board': 0, 'sockets_per_node': None, 'start_time': 1759275005, 'state_description': '', 'state_reason': 'None', 'standard_error': '', 'standard_input': '/dev/null', 'standard_output': '', 'submit_time': 1759275005, 'suspend_time': 0, 'system_comment': '', 'time_limit': None, 'time_minimum': 0, 'threads_per_core': None, 'tres_bind': '', 'tres_freq': '', 'tres_per_job': '', 'tres_per_node': 'gres:gpu:4', 'tres_per_socket': '', 'tres_per_task': '', 'tres_req_str': 'cpu=48,mem=186777M,node=1,billing=48', 'tres_alloc_str': 'cpu=48,mem=186777M,node=1,billing=48', 'user_id': 0, 'user_name': '', 'wckey': '', 'current_working_directory': '/mnt/models/mreso/monarch/examples'}, {'account': '', 'accrue_time': 1759275005, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2600', 'flags': ['TRES_STR_CALC', 'JOB_CPUS_SET ', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp2_4bbv4b/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 48.0, 'cpus_per_task': None, 'cpu_frequency_minimum': None, 'cpu_frequency_maximum': None, 'cpu_frequency_governor': None, 'cpus_per_tres': '', 'deadline': 0, 'delay_boot': 0, 'dependency': '', 'derived_exit_cod ...
# job["job_state"]='CANCELLED'
# state=CANCELLED (6)
# job["job_state"]='CANCELLED'
# state=CANCELLED (6)
# job["job_state"]='PENDING'
# state=PENDING (2)
# job["job_state"]='PENDING'
# state=PENDING (2)
# app_id='1049'
# output='{\n  "meta": {\n    "plugin": {\n      "type": "openapi\\/v0.0.37",\n      "name": "Slurm OpenAPI v0.0.37"\n    },\n    "Slurm": {\n      "version": {\n        "major": 21,\n        "micro": 5,\n        "minor": 8\n      },\n      "release": "21.08.5"\n    }\n  },\n  "errors": [\n  ],\n  "jobs": [\n    {\n      "account": "",\n      "accrue_time": 1759275005,\n      "admin_comment": "",\n      "array_job_id": 0,\n      "array_task_id": null,\n      "array_max_tasks": 0,\n      "array_task_string": "",\n      "association_id": 0,\n      "batch_features": "",\n      "batch_flag": true,\n      "batch_host": "chi2599",\n      "flags": [\n        "TRES_STR_CALC",\n        "JOB_CPUS_SET ",\n        "JOB_MEM_SET"\n      ],\n      "burst_buffer": "",\n      "burst_buffer_state": "",\n      "cluster": "vultr-mi325x-torch",\n      "cluster_features": "",\n      "command": "\\/tmp\\/tmp2_4bbv4b\\/torchx-sbatch.sh",\n      "comment": "",\n      "contiguous": false,\n      "core_spec": null,\n      "thread_spec": null,\n      "cores_per_socket": null,\n      "billable_tres": 48.0,\n      "cpus_per_task": null,\n      "cpu_frequency_minimum": null,\n      "cpu_frequency_maximum": null,\n      "cpu_frequency_governor": null,\n      "cpus_per_tres": "",\n      "deadline": 0,\n      "delay_boot": 0,\n      "dependency": "",\n      "derived_exit_code": 15,\n      "eligible_time": 1759275005,\n      "end_time": 1759275047,\n      "excluded_nodes": "",\n      "exit_code": 15,\n      "features": "",\n      "federation_origin": "",\n      "federation_siblings_active": "",\n      "federation_siblings_viable": "",\n      "gres_detail": [\n      ],\n      "group_id": 0,\n      "job_id": 1046,\n      "job_resources": {\n        "nodes": "chi2599",\n        "allocated_cpus": 48,\n        "allocated_hosts": 1,\n        "allocated_nodes": {\n          "0": {\n            "sockets": {\n              "0": "unassigned"\n            },\n            "cores": {\n              "0": "unassigned",\n              "1": "unassigned",\n              "2": "unassigned",\n              "3": "unassigned",\n              "4": "unassigned",\n              "5": "unassigned",\n              "6": "unassigned",\n              "7": "unassigned",\n              "8": "unassigned",\n              "9": "unassigned",\n              "10": "unassigned",\n              "11": "unassigned",\n              "12": "unassigned",\n              "13": "unassigned",\n              "14": "unassigned",\n              "15": "unassigned",\n              "16": "unassigned",\n              "17": "unassigned",\n              "18": "unassigned",\n              "19": "unassigned",\n              "20": "unassigned",\n              "21": "unassigned",\n              "22": "unassigned",\n              "23": "unassigned"\n            },\n            "memory": 186777,\n            "cpus": 48\n          }\n        }\n      },\n      "job_state": "CANCELLED",\n      "last_sched_evaluation": 1759275005,\n      "licenses": "",\n      "max_cpus": 0,\n      "max_nodes": 0,\n      "mcs_label": "",\n      "memory_per_tres": "",\n      "name": "mesh0-0",\n      "nodes": "chi2599",\n      "nice": null,\n      "tasks_per_core": null,\n      "tasks_per_node": 1,\n      "tasks_per_socket": null,\n      "tasks_per_board": 0,\n      "cpus": 48,\n      "node_count": 1,\n      "tasks": 1,\n      "het_job_id": 1046,\n      "het_job_id_set": "1046-1047",\n      "het_job_offset": 0,\n      "partition": "vultr-mi325x-torch",\n      "memory_per_node": 186777,\n      "memory_per_cpu": null,\n      "minimum_cpus_per_node": 48,\n      "minimum_tmp_disk_per_node": 0,\n      "preempt_time": 0,\n      "pre_sus_time": 0,\n      "priority": 4294901080,\n      "profile": null,\n      "qos": "",\n      "reboot": false,\n      "required_nodes": "",\n      "requeue": true,\n      "resize_time": 0,\n      "restart_cnt": 0,\n      "resv_name": "",\n      "shared": null,\n      "show_flags": [\n        "SHOW_ALL",\n        "SHOW_DETAIL", ...
# jobs=[{'account': '', 'accrue_time': 1759275005, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2599', 'flags': ['TRES_STR_CALC', 'JOB_CPUS_SET ', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp2_4bbv4b/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 48.0, 'cpus_per_task': None, 'cpu_frequency_minimum': None, 'cpu_frequency_maximum': None, 'cpu_frequency_governor': None, 'cpus_per_tres': '', 'deadline': 0, 'delay_boot': 0, 'dependency': '', 'derived_exit_code': 15, 'eligible_time': 1759275005, 'end_time': 1759275047, 'excluded_nodes': '', 'exit_code': 15, 'features': '', 'federation_origin': '', 'federation_siblings_active': '', 'federation_siblings_viable': '', 'gres_detail': [], 'group_id': 0, 'job_id': 1046, 'job_resources': {'nodes': 'chi2599', 'allocated_cpus': 48, 'allocated_hosts': 1, 'allocated_nodes': {'0': {'sockets': {'0': 'unassigned'}, 'cores': {'0': 'unassigned', '1': 'unassigned', '2': 'unassigned', '3': 'unassigned', '4': 'unassigned', '5': 'unassigned', '6': 'unassigned', '7': 'unassigned', '8': 'unassigned', '9': 'unassigned', '10': 'unassigned', '11': 'unassigned', '12': 'unassigned', '13': 'unassigned', '14': 'unassigned', '15': 'unassigned', '16': 'unassigned', '17': 'unassigned', '18': 'unassigned', '19': 'unassigned', '20': 'unassigned', '21': 'unassigned', '22': 'unassigned', '23': 'unassigned'}, 'memory': 186777, 'cpus': 48}}}, 'job_state': 'CANCELLED', 'last_sched_evaluation': 1759275005, 'licenses': '', 'max_cpus': 0, 'max_nodes': 0, 'mcs_label': '', 'memory_per_tres': '', 'name': 'mesh0-0', 'nodes': 'chi2599', 'nice': None, 'tasks_per_core': None, 'tasks_per_node': 1, 'tasks_per_socket': None, 'tasks_per_board': 0, 'cpus': 48, 'node_count': 1, 'tasks': 1, 'het_job_id': 1046, 'het_job_id_set': '1046-1047', 'het_job_offset': 0, 'partition': 'vultr-mi325x-torch', 'memory_per_node': 186777, 'memory_per_cpu': None, 'minimum_cpus_per_node': 48, 'minimum_tmp_disk_per_node': 0, 'preempt_time': 0, 'pre_sus_time': 0, 'priority': 4294901080, 'profile': None, 'qos': '', 'reboot': False, 'required_nodes': '', 'requeue': True, 'resize_time': 0, 'restart_cnt': 0, 'resv_name': '', 'shared': None, 'show_flags': ['SHOW_ALL', 'SHOW_DETAIL', 'SHOW_LOCAL'], 'sockets_per_board': 0, 'sockets_per_node': None, 'start_time': 1759275005, 'state_description': '', 'state_reason': 'None', 'standard_error': '', 'standard_input': '/dev/null', 'standard_output': '', 'submit_time': 1759275005, 'suspend_time': 0, 'system_comment': '', 'time_limit': None, 'time_minimum': 0, 'threads_per_core': None, 'tres_bind': '', 'tres_freq': '', 'tres_per_job': '', 'tres_per_node': 'gres:gpu:4', 'tres_per_socket': '', 'tres_per_task': '', 'tres_req_str': 'cpu=48,mem=186777M,node=1,billing=48', 'tres_alloc_str': 'cpu=48,mem=186777M,node=1,billing=48', 'user_id': 0, 'user_name': '', 'wckey': '', 'current_working_directory': '/mnt/models/mreso/monarch/examples'}, {'account': '', 'accrue_time': 1759275005, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2600', 'flags': ['TRES_STR_CALC', 'JOB_CPUS_SET ', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp2_4bbv4b/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 48.0, 'cpus_per_task': None, 'cpu_frequency_minimum': None, 'cpu_frequency_maximum': None, 'cpu_frequency_governor': None, 'cpus_per_tres': '', 'deadline': 0, 'delay_boot': 0, 'dependency': '', 'derived_exit_cod ...
# job["job_state"]='CANCELLED'
# state=CANCELLED (6)
# job["job_state"]='CANCELLED'
# state=CANCELLED (6)
# job["job_state"]='PENDING'
# state=PENDING (2)
# job["job_state"]='PENDING'
# state=PENDING (2)
# Waiting for slurm:///1049 to be RUNNING (current: PENDING); will check again in 5.0 seconds. Total wait time: 0:00:00.010575
# slurm.utils 2025-09-30 23:31:47 INFO
# ===== Server Info =====
# {
#   "name": "1049",
#   "server_handle": "slurm:///1049",
#   "state": "RUNNING",
#   "meshes": {
#     "mesh0": {
#       "host_type": "__UNSET__",
#       "hosts": 4,
#       "gpus": -1,
#       "hostnames": [
#         "chi2599",
#         "chi2599",
#         "chi2600",
#         "chi2600"
#       ]
#     }
#   }
# }
# asyncio 2025-09-30 23:31:47 DEBUG Using selector: EpollSelector
# monarch._src.actor.allocator 2025-09-30 23:31:47 INFO no match label `procmesh.monarch.meta.com/name` specified in alloc constraints
# monarch._src.actor.allocator 2025-09-30 23:31:47 INFO found a single proc mesh `mesh0` in slurm:///1049, will allocate on it
# monarch.tools.network 2025-09-30 23:31:47 INFO no AF_INET6 address that can bind TCP sockets for `chi2599:26600` (error: [Errno -3] Temporary failure in name resolution)
# monarch.tools.network 2025-09-30 23:31:47 INFO resolved AF_INET address `108.61.203.106:26600` for `chi2599:26600`
# monarch.tools.network 2025-09-30 23:31:47 INFO no AF_INET6 address that can bind TCP sockets for `chi2599:26600` (error: [Errno -3] Temporary failure in name resolution)
# monarch.tools.network 2025-09-30 23:31:47 INFO resolved AF_INET address `108.61.203.106:26600` for `chi2599:26600`
# monarch.tools.network 2025-09-30 23:31:47 INFO no AF_INET6 address that can bind TCP sockets for `chi2600:26600` (error: [Errno -3] Temporary failure in name resolution)
# monarch.tools.network 2025-09-30 23:31:47 INFO resolved AF_INET address `45.63.68.72:26600` for `chi2600:26600`
# monarch.tools.network 2025-09-30 23:31:47 INFO no AF_INET6 address that can bind TCP sockets for `chi2600:26600` (error: [Errno -3] Temporary failure in name resolution)
# monarch.tools.network 2025-09-30 23:31:47 INFO resolved AF_INET address `45.63.68.72:26600` for `chi2600:26600`
# monarch._src.actor.allocator 2025-09-30 23:31:47 INFO initializing alloc on remote allocator addresses: ['tcp!108.61.203.106:26600', 'tcp!108.61.203.106:26600', 'tcp!45.63.68.72:26600', 'tcp!45.63.68.72:26600']
# asyncio 2025-09-30 23:31:47 DEBUG Using selector: EpollSelector
# monarch._src.actor.allocator 2025-09-30 23:31:47 INFO no match label `procmesh.monarch.meta.com/name` specified in alloc constraints
# monarch._src.actor.allocator 2025-09-30 23:31:47 INFO found a single proc mesh `mesh0` in slurm:///1049, will allocate on it
# monarch.tools.network 2025-09-30 23:31:47 INFO no AF_INET6 address that can bind TCP sockets for `chi2599:26600` (error: [Errno -3] Temporary failure in name resolution)
# monarch.tools.network 2025-09-30 23:31:47 INFO resolved AF_INET address `108.61.203.106:26600` for `chi2599:26600`
# monarch.tools.network 2025-09-30 23:31:47 INFO no AF_INET6 address that can bind TCP sockets for `chi2599:26600` (error: [Errno -3] Temporary failure in name resolution)
# monarch.tools.network 2025-09-30 23:31:47 INFO resolved AF_INET address `108.61.203.106:26600` for `chi2599:26600`
# monarch.tools.network 2025-09-30 23:31:47 INFO no AF_INET6 address that can bind TCP sockets for `chi2600:26600` (error: [Errno -3] Temporary failure in name resolution)
# monarch.tools.network 2025-09-30 23:31:47 INFO resolved AF_INET address `45.63.68.72:26600` for `chi2600:26600`
# monarch.tools.network 2025-09-30 23:31:47 INFO no AF_INET6 address that can bind TCP sockets for `chi2600:26600` (error: [Errno -3] Temporary failure in name resolution)
# monarch.tools.network 2025-09-30 23:31:47 INFO resolved AF_INET address `45.63.68.72:26600` for `chi2600:26600`
# monarch._src.actor.allocator 2025-09-30 23:31:47 INFO initializing alloc on remote allocator addresses: ['tcp!108.61.203.106:26600', 'tcp!108.61.203.106:26600', 'tcp!45.63.68.72:26600', 'tcp!45.63.68.72:26600']
# app_id='1049'
# output='{\n  "meta": {\n    "plugin": {\n      "type": "openapi\\/v0.0.37",\n      "name": "Slurm OpenAPI v0.0.37"\n    },\n    "Slurm": {\n      "version": {\n        "major": 21,\n        "micro": 5,\n        "minor": 8\n      },\n      "release": "21.08.5"\n    }\n  },\n  "errors": [\n  ],\n  "jobs": [\n    {\n      "account": "",\n      "accrue_time": 1759275005,\n      "admin_comment": "",\n      "array_job_id": 0,\n      "array_task_id": null,\n      "array_max_tasks": 0,\n      "array_task_string": "",\n      "association_id": 0,\n      "batch_features": "",\n      "batch_flag": true,\n      "batch_host": "chi2599",\n      "flags": [\n        "TRES_STR_CALC",\n        "JOB_CPUS_SET ",\n        "JOB_MEM_SET"\n      ],\n      "burst_buffer": "",\n      "burst_buffer_state": "",\n      "cluster": "vultr-mi325x-torch",\n      "cluster_features": "",\n      "command": "\\/tmp\\/tmp2_4bbv4b\\/torchx-sbatch.sh",\n      "comment": "",\n      "contiguous": false,\n      "core_spec": null,\n      "thread_spec": null,\n      "cores_per_socket": null,\n      "billable_tres": 48.0,\n      "cpus_per_task": null,\n      "cpu_frequency_minimum": null,\n      "cpu_frequency_maximum": null,\n      "cpu_frequency_governor": null,\n      "cpus_per_tres": "",\n      "deadline": 0,\n      "delay_boot": 0,\n      "dependency": "",\n      "derived_exit_code": 15,\n      "eligible_time": 1759275005,\n      "end_time": 1759275047,\n      "excluded_nodes": "",\n      "exit_code": 15,\n      "features": "",\n      "federation_origin": "",\n      "federation_siblings_active": "",\n      "federation_siblings_viable": "",\n      "gres_detail": [\n      ],\n      "group_id": 0,\n      "job_id": 1046,\n      "job_resources": {\n        "nodes": "chi2599",\n        "allocated_cpus": 48,\n        "allocated_hosts": 1,\n        "allocated_nodes": {\n          "0": {\n            "sockets": {\n              "0": "unassigned"\n            },\n            "cores": {\n              "0": "unassigned",\n              "1": "unassigned",\n              "2": "unassigned",\n              "3": "unassigned",\n              "4": "unassigned",\n              "5": "unassigned",\n              "6": "unassigned",\n              "7": "unassigned",\n              "8": "unassigned",\n              "9": "unassigned",\n              "10": "unassigned",\n              "11": "unassigned",\n              "12": "unassigned",\n              "13": "unassigned",\n              "14": "unassigned",\n              "15": "unassigned",\n              "16": "unassigned",\n              "17": "unassigned",\n              "18": "unassigned",\n              "19": "unassigned",\n              "20": "unassigned",\n              "21": "unassigned",\n              "22": "unassigned",\n              "23": "unassigned"\n            },\n            "memory": 186777,\n            "cpus": 48\n          }\n        }\n      },\n      "job_state": "CANCELLED",\n      "last_sched_evaluation": 1759275005,\n      "licenses": "",\n      "max_cpus": 0,\n      "max_nodes": 0,\n      "mcs_label": "",\n      "memory_per_tres": "",\n      "name": "mesh0-0",\n      "nodes": "chi2599",\n      "nice": null,\n      "tasks_per_core": null,\n      "tasks_per_node": 1,\n      "tasks_per_socket": null,\n      "tasks_per_board": 0,\n      "cpus": 48,\n      "node_count": 1,\n      "tasks": 1,\n      "het_job_id": 1046,\n      "het_job_id_set": "1046-1047",\n      "het_job_offset": 0,\n      "partition": "vultr-mi325x-torch",\n      "memory_per_node": 186777,\n      "memory_per_cpu": null,\n      "minimum_cpus_per_node": 48,\n      "minimum_tmp_disk_per_node": 0,\n      "preempt_time": 0,\n      "pre_sus_time": 0,\n      "priority": 4294901080,\n      "profile": null,\n      "qos": "",\n      "reboot": false,\n      "required_nodes": "",\n      "requeue": true,\n      "resize_time": 0,\n      "restart_cnt": 0,\n      "resv_name": "",\n      "shared": null,\n      "show_flags": [\n        "SHOW_ALL",\n        "SHOW_DETAIL", ...
# jobs=[{'account': '', 'accrue_time': 1759275005, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2599', 'flags': ['TRES_STR_CALC', 'JOB_CPUS_SET ', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp2_4bbv4b/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 48.0, 'cpus_per_task': None, 'cpu_frequency_minimum': None, 'cpu_frequency_maximum': None, 'cpu_frequency_governor': None, 'cpus_per_tres': '', 'deadline': 0, 'delay_boot': 0, 'dependency': '', 'derived_exit_code': 15, 'eligible_time': 1759275005, 'end_time': 1759275047, 'excluded_nodes': '', 'exit_code': 15, 'features': '', 'federation_origin': '', 'federation_siblings_active': '', 'federation_siblings_viable': '', 'gres_detail': [], 'group_id': 0, 'job_id': 1046, 'job_resources': {'nodes': 'chi2599', 'allocated_cpus': 48, 'allocated_hosts': 1, 'allocated_nodes': {'0': {'sockets': {'0': 'unassigned'}, 'cores': {'0': 'unassigned', '1': 'unassigned', '2': 'unassigned', '3': 'unassigned', '4': 'unassigned', '5': 'unassigned', '6': 'unassigned', '7': 'unassigned', '8': 'unassigned', '9': 'unassigned', '10': 'unassigned', '11': 'unassigned', '12': 'unassigned', '13': 'unassigned', '14': 'unassigned', '15': 'unassigned', '16': 'unassigned', '17': 'unassigned', '18': 'unassigned', '19': 'unassigned', '20': 'unassigned', '21': 'unassigned', '22': 'unassigned', '23': 'unassigned'}, 'memory': 186777, 'cpus': 48}}}, 'job_state': 'CANCELLED', 'last_sched_evaluation': 1759275005, 'licenses': '', 'max_cpus': 0, 'max_nodes': 0, 'mcs_label': '', 'memory_per_tres': '', 'name': 'mesh0-0', 'nodes': 'chi2599', 'nice': None, 'tasks_per_core': None, 'tasks_per_node': 1, 'tasks_per_socket': None, 'tasks_per_board': 0, 'cpus': 48, 'node_count': 1, 'tasks': 1, 'het_job_id': 1046, 'het_job_id_set': '1046-1047', 'het_job_offset': 0, 'partition': 'vultr-mi325x-torch', 'memory_per_node': 186777, 'memory_per_cpu': None, 'minimum_cpus_per_node': 48, 'minimum_tmp_disk_per_node': 0, 'preempt_time': 0, 'pre_sus_time': 0, 'priority': 4294901080, 'profile': None, 'qos': '', 'reboot': False, 'required_nodes': '', 'requeue': True, 'resize_time': 0, 'restart_cnt': 0, 'resv_name': '', 'shared': None, 'show_flags': ['SHOW_ALL', 'SHOW_DETAIL', 'SHOW_LOCAL'], 'sockets_per_board': 0, 'sockets_per_node': None, 'start_time': 1759275005, 'state_description': '', 'state_reason': 'None', 'standard_error': '', 'standard_input': '/dev/null', 'standard_output': '', 'submit_time': 1759275005, 'suspend_time': 0, 'system_comment': '', 'time_limit': None, 'time_minimum': 0, 'threads_per_core': None, 'tres_bind': '', 'tres_freq': '', 'tres_per_job': '', 'tres_per_node': 'gres:gpu:4', 'tres_per_socket': '', 'tres_per_task': '', 'tres_req_str': 'cpu=48,mem=186777M,node=1,billing=48', 'tres_alloc_str': 'cpu=48,mem=186777M,node=1,billing=48', 'user_id': 0, 'user_name': '', 'wckey': '', 'current_working_directory': '/mnt/models/mreso/monarch/examples'}, {'account': '', 'accrue_time': 1759275005, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2600', 'flags': ['TRES_STR_CALC', 'JOB_CPUS_SET ', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp2_4bbv4b/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 48.0, 'cpus_per_task': None, 'cpu_frequency_minimum': None, 'cpu_frequency_maximum': None, 'cpu_frequency_governor': None, 'cpus_per_tres': '', 'deadline': 0, 'delay_boot': 0, 'dependency': '', 'derived_exit_cod ...
# job["job_state"]='CANCELLED'
# state=CANCELLED (6)
# job["job_state"]='CANCELLED'
# state=CANCELLED (6)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# app_id='1049'
# output='{\n  "meta": {\n    "plugin": {\n      "type": "openapi\\/v0.0.37",\n      "name": "Slurm OpenAPI v0.0.37"\n    },\n    "Slurm": {\n      "version": {\n        "major": 21,\n        "micro": 5,\n        "minor": 8\n      },\n      "release": "21.08.5"\n    }\n  },\n  "errors": [\n  ],\n  "jobs": [\n    {\n      "account": "",\n      "accrue_time": 1759275005,\n      "admin_comment": "",\n      "array_job_id": 0,\n      "array_task_id": null,\n      "array_max_tasks": 0,\n      "array_task_string": "",\n      "association_id": 0,\n      "batch_features": "",\n      "batch_flag": true,\n      "batch_host": "chi2599",\n      "flags": [\n        "TRES_STR_CALC",\n        "JOB_CPUS_SET ",\n        "JOB_MEM_SET"\n      ],\n      "burst_buffer": "",\n      "burst_buffer_state": "",\n      "cluster": "vultr-mi325x-torch",\n      "cluster_features": "",\n      "command": "\\/tmp\\/tmp2_4bbv4b\\/torchx-sbatch.sh",\n      "comment": "",\n      "contiguous": false,\n      "core_spec": null,\n      "thread_spec": null,\n      "cores_per_socket": null,\n      "billable_tres": 48.0,\n      "cpus_per_task": null,\n      "cpu_frequency_minimum": null,\n      "cpu_frequency_maximum": null,\n      "cpu_frequency_governor": null,\n      "cpus_per_tres": "",\n      "deadline": 0,\n      "delay_boot": 0,\n      "dependency": "",\n      "derived_exit_code": 15,\n      "eligible_time": 1759275005,\n      "end_time": 1759275047,\n      "excluded_nodes": "",\n      "exit_code": 15,\n      "features": "",\n      "federation_origin": "",\n      "federation_siblings_active": "",\n      "federation_siblings_viable": "",\n      "gres_detail": [\n      ],\n      "group_id": 0,\n      "job_id": 1046,\n      "job_resources": {\n        "nodes": "chi2599",\n        "allocated_cpus": 48,\n        "allocated_hosts": 1,\n        "allocated_nodes": {\n          "0": {\n            "sockets": {\n              "0": "unassigned"\n            },\n            "cores": {\n              "0": "unassigned",\n              "1": "unassigned",\n              "2": "unassigned",\n              "3": "unassigned",\n              "4": "unassigned",\n              "5": "unassigned",\n              "6": "unassigned",\n              "7": "unassigned",\n              "8": "unassigned",\n              "9": "unassigned",\n              "10": "unassigned",\n              "11": "unassigned",\n              "12": "unassigned",\n              "13": "unassigned",\n              "14": "unassigned",\n              "15": "unassigned",\n              "16": "unassigned",\n              "17": "unassigned",\n              "18": "unassigned",\n              "19": "unassigned",\n              "20": "unassigned",\n              "21": "unassigned",\n              "22": "unassigned",\n              "23": "unassigned"\n            },\n            "memory": 186777,\n            "cpus": 48\n          }\n        }\n      },\n      "job_state": "CANCELLED",\n      "last_sched_evaluation": 1759275005,\n      "licenses": "",\n      "max_cpus": 0,\n      "max_nodes": 0,\n      "mcs_label": "",\n      "memory_per_tres": "",\n      "name": "mesh0-0",\n      "nodes": "chi2599",\n      "nice": null,\n      "tasks_per_core": null,\n      "tasks_per_node": 1,\n      "tasks_per_socket": null,\n      "tasks_per_board": 0,\n      "cpus": 48,\n      "node_count": 1,\n      "tasks": 1,\n      "het_job_id": 1046,\n      "het_job_id_set": "1046-1047",\n      "het_job_offset": 0,\n      "partition": "vultr-mi325x-torch",\n      "memory_per_node": 186777,\n      "memory_per_cpu": null,\n      "minimum_cpus_per_node": 48,\n      "minimum_tmp_disk_per_node": 0,\n      "preempt_time": 0,\n      "pre_sus_time": 0,\n      "priority": 4294901080,\n      "profile": null,\n      "qos": "",\n      "reboot": false,\n      "required_nodes": "",\n      "requeue": true,\n      "resize_time": 0,\n      "restart_cnt": 0,\n      "resv_name": "",\n      "shared": null,\n      "show_flags": [\n        "SHOW_ALL",\n        "SHOW_DETAIL", ...
# jobs=[{'account': '', 'accrue_time': 1759275005, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2599', 'flags': ['TRES_STR_CALC', 'JOB_CPUS_SET ', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp2_4bbv4b/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 48.0, 'cpus_per_task': None, 'cpu_frequency_minimum': None, 'cpu_frequency_maximum': None, 'cpu_frequency_governor': None, 'cpus_per_tres': '', 'deadline': 0, 'delay_boot': 0, 'dependency': '', 'derived_exit_code': 15, 'eligible_time': 1759275005, 'end_time': 1759275047, 'excluded_nodes': '', 'exit_code': 15, 'features': '', 'federation_origin': '', 'federation_siblings_active': '', 'federation_siblings_viable': '', 'gres_detail': [], 'group_id': 0, 'job_id': 1046, 'job_resources': {'nodes': 'chi2599', 'allocated_cpus': 48, 'allocated_hosts': 1, 'allocated_nodes': {'0': {'sockets': {'0': 'unassigned'}, 'cores': {'0': 'unassigned', '1': 'unassigned', '2': 'unassigned', '3': 'unassigned', '4': 'unassigned', '5': 'unassigned', '6': 'unassigned', '7': 'unassigned', '8': 'unassigned', '9': 'unassigned', '10': 'unassigned', '11': 'unassigned', '12': 'unassigned', '13': 'unassigned', '14': 'unassigned', '15': 'unassigned', '16': 'unassigned', '17': 'unassigned', '18': 'unassigned', '19': 'unassigned', '20': 'unassigned', '21': 'unassigned', '22': 'unassigned', '23': 'unassigned'}, 'memory': 186777, 'cpus': 48}}}, 'job_state': 'CANCELLED', 'last_sched_evaluation': 1759275005, 'licenses': '', 'max_cpus': 0, 'max_nodes': 0, 'mcs_label': '', 'memory_per_tres': '', 'name': 'mesh0-0', 'nodes': 'chi2599', 'nice': None, 'tasks_per_core': None, 'tasks_per_node': 1, 'tasks_per_socket': None, 'tasks_per_board': 0, 'cpus': 48, 'node_count': 1, 'tasks': 1, 'het_job_id': 1046, 'het_job_id_set': '1046-1047', 'het_job_offset': 0, 'partition': 'vultr-mi325x-torch', 'memory_per_node': 186777, 'memory_per_cpu': None, 'minimum_cpus_per_node': 48, 'minimum_tmp_disk_per_node': 0, 'preempt_time': 0, 'pre_sus_time': 0, 'priority': 4294901080, 'profile': None, 'qos': '', 'reboot': False, 'required_nodes': '', 'requeue': True, 'resize_time': 0, 'restart_cnt': 0, 'resv_name': '', 'shared': None, 'show_flags': ['SHOW_ALL', 'SHOW_DETAIL', 'SHOW_LOCAL'], 'sockets_per_board': 0, 'sockets_per_node': None, 'start_time': 1759275005, 'state_description': '', 'state_reason': 'None', 'standard_error': '', 'standard_input': '/dev/null', 'standard_output': '', 'submit_time': 1759275005, 'suspend_time': 0, 'system_comment': '', 'time_limit': None, 'time_minimum': 0, 'threads_per_core': None, 'tres_bind': '', 'tres_freq': '', 'tres_per_job': '', 'tres_per_node': 'gres:gpu:4', 'tres_per_socket': '', 'tres_per_task': '', 'tres_req_str': 'cpu=48,mem=186777M,node=1,billing=48', 'tres_alloc_str': 'cpu=48,mem=186777M,node=1,billing=48', 'user_id': 0, 'user_name': '', 'wckey': '', 'current_working_directory': '/mnt/models/mreso/monarch/examples'}, {'account': '', 'accrue_time': 1759275005, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2600', 'flags': ['TRES_STR_CALC', 'JOB_CPUS_SET ', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp2_4bbv4b/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 48.0, 'cpus_per_task': None, 'cpu_frequency_minimum': None, 'cpu_frequency_maximum': None, 'cpu_frequency_governor': None, 'cpus_per_tres': '', 'deadline': 0, 'delay_boot': 0, 'dependency': '', 'derived_exit_cod ...
# job["job_state"]='CANCELLED'
# state=CANCELLED (6)
# job["job_state"]='CANCELLED'
# state=CANCELLED (6)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# New job `slurm:///1049` is ready to serve.
# CREATE PROC MESH
# SPAWN ACTORS
# SETUP ENV
# app_id='1049'
# output='{\n  "meta": {\n    "plugin": {\n      "type": "openapi\\/v0.0.37",\n      "name": "Slurm OpenAPI v0.0.37"\n    },\n    "Slurm": {\n      "version": {\n        "major": 21,\n        "micro": 5,\n        "minor": 8\n      },\n      "release": "21.08.5"\n    }\n  },\n  "errors": [\n  ],\n  "jobs": [\n    {\n      "account": "",\n      "accrue_time": 1759275005,\n      "admin_comment": "",\n      "array_job_id": 0,\n      "array_task_id": null,\n      "array_max_tasks": 0,\n      "array_task_string": "",\n      "association_id": 0,\n      "batch_features": "",\n      "batch_flag": true,\n      "batch_host": "chi2599",\n      "flags": [\n        "TRES_STR_CALC",\n        "JOB_CPUS_SET ",\n        "JOB_MEM_SET"\n      ],\n      "burst_buffer": "",\n      "burst_buffer_state": "",\n      "cluster": "vultr-mi325x-torch",\n      "cluster_features": "",\n      "command": "\\/tmp\\/tmp2_4bbv4b\\/torchx-sbatch.sh",\n      "comment": "",\n      "contiguous": false,\n      "core_spec": null,\n      "thread_spec": null,\n      "cores_per_socket": null,\n      "billable_tres": 48.0,\n      "cpus_per_task": null,\n      "cpu_frequency_minimum": null,\n      "cpu_frequency_maximum": null,\n      "cpu_frequency_governor": null,\n      "cpus_per_tres": "",\n      "deadline": 0,\n      "delay_boot": 0,\n      "dependency": "",\n      "derived_exit_code": 15,\n      "eligible_time": 1759275005,\n      "end_time": 1759275047,\n      "excluded_nodes": "",\n      "exit_code": 15,\n      "features": "",\n      "federation_origin": "",\n      "federation_siblings_active": "",\n      "federation_siblings_viable": "",\n      "gres_detail": [\n      ],\n      "group_id": 0,\n      "job_id": 1046,\n      "job_resources": {\n        "nodes": "chi2599",\n        "allocated_cpus": 48,\n        "allocated_hosts": 1,\n        "allocated_nodes": {\n          "0": {\n            "sockets": {\n              "0": "unassigned"\n            },\n            "cores": {\n              "0": "unassigned",\n              "1": "unassigned",\n              "2": "unassigned",\n              "3": "unassigned",\n              "4": "unassigned",\n              "5": "unassigned",\n              "6": "unassigned",\n              "7": "unassigned",\n              "8": "unassigned",\n              "9": "unassigned",\n              "10": "unassigned",\n              "11": "unassigned",\n              "12": "unassigned",\n              "13": "unassigned",\n              "14": "unassigned",\n              "15": "unassigned",\n              "16": "unassigned",\n              "17": "unassigned",\n              "18": "unassigned",\n              "19": "unassigned",\n              "20": "unassigned",\n              "21": "unassigned",\n              "22": "unassigned",\n              "23": "unassigned"\n            },\n            "memory": 186777,\n            "cpus": 48\n          }\n        }\n      },\n      "job_state": "CANCELLED",\n      "last_sched_evaluation": 1759275005,\n      "licenses": "",\n      "max_cpus": 0,\n      "max_nodes": 0,\n      "mcs_label": "",\n      "memory_per_tres": "",\n      "name": "mesh0-0",\n      "nodes": "chi2599",\n      "nice": null,\n      "tasks_per_core": null,\n      "tasks_per_node": 1,\n      "tasks_per_socket": null,\n      "tasks_per_board": 0,\n      "cpus": 48,\n      "node_count": 1,\n      "tasks": 1,\n      "het_job_id": 1046,\n      "het_job_id_set": "1046-1047",\n      "het_job_offset": 0,\n      "partition": "vultr-mi325x-torch",\n      "memory_per_node": 186777,\n      "memory_per_cpu": null,\n      "minimum_cpus_per_node": 48,\n      "minimum_tmp_disk_per_node": 0,\n      "preempt_time": 0,\n      "pre_sus_time": 0,\n      "priority": 4294901080,\n      "profile": null,\n      "qos": "",\n      "reboot": false,\n      "required_nodes": "",\n      "requeue": true,\n      "resize_time": 0,\n      "restart_cnt": 0,\n      "resv_name": "",\n      "shared": null,\n      "show_flags": [\n        "SHOW_ALL",\n        "SHOW_DETAIL", ...
# jobs=[{'account': '', 'accrue_time': 1759275005, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2599', 'flags': ['TRES_STR_CALC', 'JOB_CPUS_SET ', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp2_4bbv4b/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 48.0, 'cpus_per_task': None, 'cpu_frequency_minimum': None, 'cpu_frequency_maximum': None, 'cpu_frequency_governor': None, 'cpus_per_tres': '', 'deadline': 0, 'delay_boot': 0, 'dependency': '', 'derived_exit_code': 15, 'eligible_time': 1759275005, 'end_time': 1759275047, 'excluded_nodes': '', 'exit_code': 15, 'features': '', 'federation_origin': '', 'federation_siblings_active': '', 'federation_siblings_viable': '', 'gres_detail': [], 'group_id': 0, 'job_id': 1046, 'job_resources': {'nodes': 'chi2599', 'allocated_cpus': 48, 'allocated_hosts': 1, 'allocated_nodes': {'0': {'sockets': {'0': 'unassigned'}, 'cores': {'0': 'unassigned', '1': 'unassigned', '2': 'unassigned', '3': 'unassigned', '4': 'unassigned', '5': 'unassigned', '6': 'unassigned', '7': 'unassigned', '8': 'unassigned', '9': 'unassigned', '10': 'unassigned', '11': 'unassigned', '12': 'unassigned', '13': 'unassigned', '14': 'unassigned', '15': 'unassigned', '16': 'unassigned', '17': 'unassigned', '18': 'unassigned', '19': 'unassigned', '20': 'unassigned', '21': 'unassigned', '22': 'unassigned', '23': 'unassigned'}, 'memory': 186777, 'cpus': 48}}}, 'job_state': 'CANCELLED', 'last_sched_evaluation': 1759275005, 'licenses': '', 'max_cpus': 0, 'max_nodes': 0, 'mcs_label': '', 'memory_per_tres': '', 'name': 'mesh0-0', 'nodes': 'chi2599', 'nice': None, 'tasks_per_core': None, 'tasks_per_node': 1, 'tasks_per_socket': None, 'tasks_per_board': 0, 'cpus': 48, 'node_count': 1, 'tasks': 1, 'het_job_id': 1046, 'het_job_id_set': '1046-1047', 'het_job_offset': 0, 'partition': 'vultr-mi325x-torch', 'memory_per_node': 186777, 'memory_per_cpu': None, 'minimum_cpus_per_node': 48, 'minimum_tmp_disk_per_node': 0, 'preempt_time': 0, 'pre_sus_time': 0, 'priority': 4294901080, 'profile': None, 'qos': '', 'reboot': False, 'required_nodes': '', 'requeue': True, 'resize_time': 0, 'restart_cnt': 0, 'resv_name': '', 'shared': None, 'show_flags': ['SHOW_ALL', 'SHOW_DETAIL', 'SHOW_LOCAL'], 'sockets_per_board': 0, 'sockets_per_node': None, 'start_time': 1759275005, 'state_description': '', 'state_reason': 'None', 'standard_error': '', 'standard_input': '/dev/null', 'standard_output': '', 'submit_time': 1759275005, 'suspend_time': 0, 'system_comment': '', 'time_limit': None, 'time_minimum': 0, 'threads_per_core': None, 'tres_bind': '', 'tres_freq': '', 'tres_per_job': '', 'tres_per_node': 'gres:gpu:4', 'tres_per_socket': '', 'tres_per_task': '', 'tres_req_str': 'cpu=48,mem=186777M,node=1,billing=48', 'tres_alloc_str': 'cpu=48,mem=186777M,node=1,billing=48', 'user_id': 0, 'user_name': '', 'wckey': '', 'current_working_directory': '/mnt/models/mreso/monarch/examples'}, {'account': '', 'accrue_time': 1759275005, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2600', 'flags': ['TRES_STR_CALC', 'JOB_CPUS_SET ', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp2_4bbv4b/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 48.0, 'cpus_per_task': None, 'cpu_frequency_minimum': None, 'cpu_frequency_maximum': None, 'cpu_frequency_governor': None, 'cpus_per_tres': '', 'deadline': 0, 'delay_boot': 0, 'dependency': '', 'derived_exit_cod ...
# job["job_state"]='CANCELLED'
# state=CANCELLED (6)
# job["job_state"]='CANCELLED'
# state=CANCELLED (6)
# job["job_state"]='RUNNING'
# ...
# jobs=[{'account': '', 'accrue_time': 1759275005, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2599', 'flags': ['TRES_STR_CALC', 'JOB_CPUS_SET ', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp2_4bbv4b/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 48.0, 'cpus_per_task': None, 'cpu_frequency_minimum': None, 'cpu_frequency_maximum': None, 'cpu_frequency_governor': None, 'cpus_per_tres': '', 'deadline': 0, 'delay_boot': 0, 'dependency': '', 'derived_exit_code': 15, 'eligible_time': 1759275005, 'end_time': 1759275047, 'excluded_nodes': '', 'exit_code': 15, 'features': '', 'federation_origin': '', 'federation_siblings_active': '', 'federation_siblings_viable': '', 'gres_detail': [], 'group_id': 0, 'job_id': 1046, 'job_resources': {'nodes': 'chi2599', 'allocated_cpus': 48, 'allocated_hosts': 1, 'allocated_nodes': {'0': {'sockets': {'0': 'unassigned'}, 'cores': {'0': 'unassigned', '1': 'unassigned', '2': 'unassigned', '3': 'unassigned', '4': 'unassigned', '5': 'unassigned', '6': 'unassigned', '7': 'unassigned', '8': 'unassigned', '9': 'unassigned', '10': 'unassigned', '11': 'unassigned', '12': 'unassigned', '13': 'unassigned', '14': 'unassigned', '15': 'unassigned', '16': 'unassigned', '17': 'unassigned', '18': 'unassigned', '19': 'unassigned', '20': 'unassigned', '21': 'unassigned', '22': 'unassigned', '23': 'unassigned'}, 'memory': 186777, 'cpus': 48}}}, 'job_state': 'CANCELLED', 'last_sched_evaluation': 1759275005, 'licenses': '', 'max_cpus': 0, 'max_nodes': 0, 'mcs_label': '', 'memory_per_tres': '', 'name': 'mesh0-0', 'nodes': 'chi2599', 'nice': None, 'tasks_per_core': None, 'tasks_per_node': 1, 'tasks_per_socket': None, 'tasks_per_board': 0, 'cpus': 48, 'node_count': 1, 'tasks': 1, 'het_job_id': 1046, 'het_job_id_set': '1046-1047', 'het_job_offset': 0, 'partition': 'vultr-mi325x-torch', 'memory_per_node': 186777, 'memory_per_cpu': None, 'minimum_cpus_per_node': 48, 'minimum_tmp_disk_per_node': 0, 'preempt_time': 0, 'pre_sus_time': 0, 'priority': 4294901080, 'profile': None, 'qos': '', 'reboot': False, 'required_nodes': '', 'requeue': True, 'resize_time': 0, 'restart_cnt': 0, 'resv_name': '', 'shared': None, 'show_flags': ['SHOW_ALL', 'SHOW_DETAIL', 'SHOW_LOCAL'], 'sockets_per_board': 0, 'sockets_per_node': None, 'start_time': 1759275005, 'state_description': '', 'state_reason': 'None', 'standard_error': '', 'standard_input': '/dev/null', 'standard_output': '', 'submit_time': 1759275005, 'suspend_time': 0, 'system_comment': '', 'time_limit': None, 'time_minimum': 0, 'threads_per_core': None, 'tres_bind': '', 'tres_freq': '', 'tres_per_job': '', 'tres_per_node': 'gres:gpu:4', 'tres_per_socket': '', 'tres_per_task': '', 'tres_req_str': 'cpu=48,mem=186777M,node=1,billing=48', 'tres_alloc_str': 'cpu=48,mem=186777M,node=1,billing=48', 'user_id': 0, 'user_name': '', 'wckey': '', 'current_working_directory': '/mnt/models/mreso/monarch/examples'}, {'account': '', 'accrue_time': 1759275005, 'admin_comment': '', 'array_job_id': 0, 'array_task_id': None, 'array_max_tasks': 0, 'array_task_string': '', 'association_id': 0, 'batch_features': '', 'batch_flag': True, 'batch_host': 'chi2600', 'flags': ['TRES_STR_CALC', 'JOB_CPUS_SET ', 'JOB_MEM_SET'], 'burst_buffer': '', 'burst_buffer_state': '', 'cluster': 'vultr-mi325x-torch', 'cluster_features': '', 'command': '/tmp/tmp2_4bbv4b/torchx-sbatch.sh', 'comment': '', 'contiguous': False, 'core_spec': None, 'thread_spec': None, 'cores_per_socket': None, 'billable_tres': 48.0, 'cpus_per_task': None, 'cpu_frequency_minimum': None, 'cpu_frequency_maximum': None, 'cpu_frequency_governor': None, 'cpus_per_tres': '', 'deadline': 0, 'delay_boot': 0, 'dependency': '', 'derived_exit_cod ...
# job["job_state"]='CANCELLED'
# state=CANCELLED (6)
# job["job_state"]='CANCELLED'
# state=CANCELLED (6)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# job["job_state"]='RUNNING'
# state=RUNNING (3)
# [DEBUG] start_comm_watcher: ordered_hosts.len() = 4
# [DEBUG] start_comm_watcher: ordered_hosts = [RemoteProcessAllocHost { id: "108.61.203.106", hostname: "108.61.203.106" }, RemoteProcessAllocHost { id: "108.61.203.106", hostname: "108.61.203.106" }, RemoteProcessAllocHost { id: "45.63.68.72", hostname: "45.63.68.72" }, RemoteProcessAllocHost { id: "45.63.68.72", hostname: "45.63.68.72" }]
# [DEBUG] start_comm_watcher: host_states.len() = 1
# [DEBUG] start_comm_watcher: host_states keys = ["108.61.203.106"]
# [DEBUG] start_comm_watcher: looking up host.id = "108.61.203.106"
# [DEBUG] start_comm_watcher: looking up host.id = "108.61.203.106"
# [DEBUG] start_comm_watcher: looking up host.id = "45.63.68.72"
# [-]E0930 23:31:47.696103 351268 hyperactor/src/panic_handler.rs:47] panic at hyperactor_mesh/src/alloc/remoteprocess.rs:698:60, stacktrace:   0: std::panicking::update_hook::{{closure}}
#    1: std::panicking::rust_panic_with_hook
#    2: std::panicking::begin_panic_handler::{{closure}}
#    3: std::sys::backtrace::__rust_end_short_backtrace
#    4: __rustc::rust_begin_unwind
#    5: core::panicking::panic_fmt
#    6: core::panicking::panic
#    7: core::option::unwrap_failed
#    8: <hyperactor_mesh::alloc::remoteprocess::RemoteProcessAlloc as hyperactor_mesh::alloc::Alloc>::next::{{closure}}
#    9: <A as hyperactor_mesh::alloc::AllocExt>::initialize::{{closure}}
#   10: hyperactor_mesh::proc_mesh::ProcMesh::allocate_boxed_inner::{{closure}}::{{closure}}
#   11: monarch_hyperactor::pytokio::PyPythonTask::new::{{closure}}
#   12: monarch_hyperactor::pytokio::PyPythonTask::new::{{closure}}
#   13: monarch_hyperactor::pytokio::PyPythonTask::spawn::{{closure}}
#   14: tokio::runtime::task::core::Core<T,S>::poll
#   15: tokio::runtime::task::harness::Harness<T,S>::poll
#   16: tokio::runtime::scheduler::multi_thread::worker::Context::run_task
#   17: tokio::runtime::scheduler::multi_thread::worker::Context::run
#   18: tokio::runtime::context::scoped::Scoped<T>::set
#   19: tokio::runtime::context::runtime::enter_runtime
#   20: tokio::runtime::scheduler::multi_thread::worker::run
#   21: <tokio::runtime::blocking::task::BlockingTask<T> as core::future::future::Future>::poll
#   22: tokio::runtime::task::core::Core<T,S>::poll
#   23: tokio::runtime::task::harness::Harness<T,S>::poll
#   24: tokio::runtime::blocking::pool::Inner::run
#   25: std::sys::backtrace::__rust_begin_short_backtrace
#   26: core::ops::function::FnOnce::call_once{{vtable.shim}}
#   27: std::sys::pal::unix::thread::Thread::new::thread_start
#   28: start_thread
#              at ./nptl/pthread_create.c:442:8
#   29: __GI___clone3
#              at ./misc/../sysdeps/unix/sysv/linux/x86_64/clone3.S:81:0
#
#
# thread 'tokio-runtime-worker' panicked at hyperactor_mesh/src/alloc/remoteprocess.rs:698:60:
# called `Option::unwrap()` on a `None` value
# stack backtrace:
#    0:     0x7f022938c372 - <std::sys::backtrace::BacktraceLock::print::DisplayBacktrace as core::fmt::Display>::fmt::h19cf267a69f554f4
#    1:     0x7f02293b8e73 - core::fmt::write::hb8432f4f418a4cbb
#    2:     0x7f0229387633 - std::io::Write::write_fmt::h26b8140c7e286da3
#    3:     0x7f022938c1c2 - std::sys::backtrace::BacktraceLock::print::hceb5e43a3264b978
#    4:     0x7f022938e206 - std::panicking::default_hook::{{closure}}::h777b3b3f382f0330
#    5:     0x7f022938e009 - std::panicking::default_hook::h7a8c6dca3aa5f7d6
#    6:     0x7f0228e9d072 - std::panicking::update_hook::{{closure}}::he5d5729292b7e658
#    7:     0x7f022938ecdb - std::panicking::rust_panic_with_hook::h182f60f0467d326e
#    8:     0x7f022938e976 - std::panicking::begin_panic_handler::{{closure}}::h47abc8b78d5d5acc
#    9:     0x7f022938c879 - std::sys::backtrace::__rust_end_short_backtrace::h70f5442660310bc8
#   10:     0x7f022938e63d - __rustc[90fd524071601a38]::rust_begin_unwind
#   11:     0x7f02293b6900 - core::panicking::panic_fmt::h9f95679c9d4adb8a
#   12:     0x7f02293b698c - core::panicking::panic::h57c44da2e9fd3b73
#   13:     0x7f02293b6769 - core::option::unwrap_failed::ha8069cb7685839df
#   14:     0x7f0228b914e4 - <hyperactor_mesh::alloc::remoteprocess::RemoteProcessAlloc as hyperactor_mesh::alloc::Alloc>::next::{{closure}}::h1caa6049db4b8cde
#   15:     0x7f02281aeea0 - <A as hyperactor_mesh::alloc::AllocExt>::initialize::{{closure}}::h626a0ac5a3be6b38
#   16:     0x7f02283898a1 - hyperactor_mesh::proc_mesh::ProcMesh::allocate_boxed_inner::{{closure}}::{{closure}}::h8b4dfafb9d8b960b
#   17:     0x7f02283d111c - monarch_hyperactor::pytokio::PyPythonTask::new::{{closure}}::hbe02362446aee3ac
#   18:     0x7f02283d45f3 - monarch_hyperactor::pytokio::PyPythonTask::new::{{closure}}::heee82e15c471ba9b
#   19:     0x7f02280d6171 - monarch_hyperactor::pytokio::PyPythonTask::spawn::{{closure}}::h7d620eb834746f85
#   20:     0x7f02280bbac4 - tokio::runtime::task::core::Core<T,S>::poll::h63ff3ad7680a781b
#   21:     0x7f02285dd52f - tokio::runtime::task::harness::Harness<T,S>::poll::hc2ef0c4afc95a206
#   22:     0x7f02293407eb - tokio::runtime::scheduler::multi_thread::worker::Context::run_task::h44e0f00246fb70e0
#   23:     0x7f022933fcd0 - tokio::runtime::scheduler::multi_thread::worker::Context::run::hde6ea640e40872b2
#   24:     0x7f022933a5f8 - tokio::runtime::context::scoped::Scoped<T>::set::h268f432437a8684e
#   25:     0x7f022931767a - tokio::runtime::context::runtime::enter_runtime::hd4bc43a7fbc6ce8b
#   26:     0x7f022933f54d - tokio::runtime::scheduler::multi_thread::worker::run::ha15b134c52abd901
#   27:     0x7f02293259bd - <tokio::runtime::blocking::task::BlockingTask<T> as core::future::future::Future>::poll::h2583bc0be8e40407
#   28:     0x7f0229338627 - tokio::runtime::task::core::Core<T,S>::poll::h8c56c0b17aa26ed4
#   29:     0x7f0229312561 - tokio::runtime::task::harness::Harness<T,S>::poll::hedb034605f654caf
#   30:     0x7f0229334997 - tokio::runtime::blocking::pool::Inner::run::h4b14f46f1bea28a2
#   31:     0x7f0229320cb7 - std::sys::backtrace::__rust_begin_short_backtrace::hed1eea325b852791
#   32:     0x7f0229341872 - core::ops::function::FnOnce::call_once{{vtable.shim}}::h5023a8130c6c94ed
#   33:     0x7f0229391af7 - std::sys::pal::unix::thread::Thread::new::thread_start::h7085bbf7ab17226b
#   34:     0x7f0482b3bac3 - start_thread
#                                at ./nptl/pthread_create.c:442:8
#   35:     0x7f0482bcd850 - __GI___clone3
#                                at ./misc/../sysdeps/unix/sysv/linux/x86_64/clone3.S:81:0
#   36:                0x0 - <unknown>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 134
#     130         commands.kill(f"slurm:///{server_info.name}")
#     133 if __name__ == "__main__":
# --> 134     await main()
#
# Cell In[14], line 119, in main()
#     117 ddp_actor = proc_mesh.spawn("ddp_actor", DDPActor)
#     118 print("SETUP ENV")
# --> 119 await setup_env_for_distributed(proc_mesh)
#     120 print("SETUP CALL")
#     121 await ddp_actor.setup.call()
#
# File /mnt/models/mreso/monarch/python/monarch/utils/utils.py:75, in setup_env_for_distributed(proc_mesh, master_addr, master_port)
#      72 am = await proc_mesh.spawn("_TorchDistributedInitActor", _TorchDistributedInitActor)
#      73 if master_addr is None:
#      74     # We use call instead of call_one because call_one can't handle tuple return types.
# ---> 75     vm = await am.flatten("rank").slice(rank=0).get_host_port.call()
#      76     master_addr, master_port = vm.item()
#      77 assert master_port is not None, "master_port should not be None here."
#
# File /mnt/models/mreso/monarch/python/monarch/_src/actor/future.py:136, in Future.__await__.<locals>.mark_complete()
#     134 async def mark_complete():
#     135     try:
# --> 136         func, value = fut.set_result, await coro
#     137     except Exception as e:
#     138         func, value = fut.set_exception, e
#
# File /mnt/models/mreso/monarch/python/monarch/_src/actor/endpoint.py:135, in Endpoint.call.<locals>.process()
#     133 results: List[R] = [None] * extent.nelements  # pyre-fixme[9]
#     134 for _ in range(extent.nelements):
# --> 135     rank, value = await r._recv()
#     136     results[rank] = value
#     137 call_shape = Shape(
#     138     extent.labels,
#     139     NDSlice.new_row_major(extent.sizes),
#     140 )
#
# File /mnt/models/mreso/monarch/python/monarch/_src/actor/actor_mesh.py:798, in PortReceiver._recv(self)
#     795     result = await awaitable
#     796 else:
#     797     # type: ignore
# --> 798     result, i = await PythonTask.select_one([self._monitor.task(), awaitable])
#     799     if i == 0:
#     800         raise result
#
# File /mnt/models/mreso/monarch/python/monarch/_src/actor/proc_mesh.py:359, in ProcMesh.from_alloc.<locals>.task(pm, hy_proc_mesh_task, setup_actor, stream_log_to_client)
#     353 async def task(
#     354     pm: "ProcMesh",
#     355     hy_proc_mesh_task: "Shared[HyProcMesh]",
#     356     setup_actor: Optional[SetupActor],
#     357     stream_log_to_client: bool,
#     358 ) -> HyProcMesh:
# --> 359     hy_proc_mesh = await hy_proc_mesh_task
#     361     await pm._logging_manager.init(hy_proc_mesh, stream_log_to_client)
#     363     if setup_actor is not None:
#
# ValueError: channel closed
# [-]E0930 23:32:18.364202 351268 hyperactor/src/channel/net.rs:875] error_msg:session tcp:108.61.203.106:26600.10146302124491655236: failed to deliver message within timeout
# [-]E0930 23:32:18.393329 351268 hyperactor/src/channel/net.rs:875] error_msg:session tcp:108.61.203.106:26600.7179995229651347464: failed to deliver message within timeout
